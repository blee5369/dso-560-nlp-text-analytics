# %% [markdown]
# ## TF-IDF Amazon
#
# You are an analyst working for Amazon's product team, and charged with identifying areas for improvement for the toy reviews.
#
# Using the **amazon-[poor|good]-reviews.csv** dataset, clean and parse the text reviews. Explain the decisions you make:
# - why remove/keep stopwords?
# - which stopwords to remove?
# - stemming versus lemmatization?
# - regex cleaning and substitution?
# - adding in custom stopwords?
# - what `n` for your `n-grams`?
# - which words to collocate together?
#
# Finally, generate a TF-IDF report that explains for a business (non-technical) stakeholder:
# * the features your analysis showed that customers cited as reasons for a poor review
# * the features your analysis showed that customers cited as reasons for a good review
# * the most common issues identified from your analysis that generated customer dissatisfaction.
#
# Explain to what degree the TF-IDF findings make sense - what are its limitations?

# %%
import re
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from matplotlib.pyplot import figure


import nltk


from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet


from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
bads = open('poor_amazon_toy_reviews.txt', 'r', encoding="utf8").readlines()
goods = open('good_amazon_toy_reviews.txt', 'r', encoding="utf8").readlines()

# %% [markdown]
# ### Cleaning and Stopword removal
#
# Lets clean up the data by checking and removing garbage values (this code stolen from my previous HW), and then lets remove stopwords based on our custom list

# %%
def find_unique_characters(regex, lines):
    """
    Finds unique characters from a list of strings, almost certainly inefficiently 
    
    """
    #Match anything that is non alpha-numeric or whitespace, creates list of lists of matching characters
    potential_malforms = [re.findall(regex, review) for review in lines]

    #lets whittle down this list of lists to a unqiue list, btw this took me way longer than it needed to
    unique_malforms = set([char for review in potential_malforms for char in review])
    
    print(F"Number of unique potential Malformed Characters: {len(unique_malforms)}, \n\nCandidates: {unique_malforms}")
    return unique_malforms

# %% [markdown]
# ### Utility functions

# %%
def cleaner(data):
    cleaned=[" ".join(re.findall("[a-zA-z0-9]+",i)).lower() for i in data]
    return cleaned

def count_words(lines, delimiter=" "):
    
    words = Counter() # instantiate a Counter object called words
    for line in lines:
        for word in line.split(delimiter):
            words[word] += 1 # increment count for word
    return words

# %%
# %time 
stolen_unique_malforms = find_unique_characters(r"[\W ]", goods+bads)
# Out:
# Wall time: 0 ns
# Number of unique potential Malformed Characters: 228,
#
# Candidates: {'▽', '☀', '♡', '😴', '＿', '😷', '＾', '👀', '|', '‘', '😝', '–', '。', '\xa0', '◄', '🏼', '💛', '*', '（', '🚮', '）', '“', '—', '<', '😀', '☹', '͡', '⚾', '😗', '´', '😛', '👧', '・', '░', '🌴', '͜', '😪', '👎', '\u3000', '😨', '¿', '😻', '😡', '😞', '☺', '🙂', '😠', '😜', '♥', '🐌', '😯', '+', '🎶', '🐶', '@', '}', '🙌', '🐮', '😢', '😆', '✴', '😭', '😬', '$', '™', '❤', '💞', '😩', '😫', '😐', '😄', '\n', '⌒', '💔', '🐘', '✋', '🔫', '😏', '∩', '🏿', '😃', '🍟', '🐜', '?', '£', '🎃', '💕', '💁', '🌵', ' ', '!', '💖', '"', '👨', '`', '🙅', '%', '😁', '😥', '🐝', '😟', '🍴', '😱', '♪', '✔', '›', '⁃', '💪', '🐣', '✌', "'", '🏃', '😇', '，', '😒', '″', '👏', '🐧', '😘', '￣', '🙏', '»', '👩', '🍦', '😳', '•', '≡', '∀', '🏽', '😎', '😂', '😚', '💥', '🍂', '🐩', '\u200b', '🐗', '☆', '\x1a', '💯', '❗', '👌', '😲', '[', '≦', '🚗', '.', '💘', '😈', '😮', '\\', '😍', ')', '&', '😰', '-', '⁄', '●', '«', '🐬', '😙', '🐻', '️', '≧', '💀', '🍔', '🐞', '⭐', '°', '👻', '\u200d', ':', '😖', '×', '►', '👽', '🎪', '^', '👍', '🐷', '‹', '😤', '💙', '💝', '>', '®', ']', '#', ',', '/', '💚', '😾', '(', '✨', '😅', '¨', ';', '~', '★', '🏾', '🐍', '¯', '🐇', '？', '’', '📱', '…', '=', '😉', '💗', '😋', '∇', '💜', '¦', '{', '¡', '😕', '😶', '☝', '😔', '\x1b', '🎉', '～', '🏻', '😊', '💓', '”', '！'}

# %% [markdown]
# ### Removing all malformed / Unecessary Characters

# %%
#SANITY CHECK: make sure the list comprehension works like i think it does
bad_cleaned_reviews = [re.sub(r"[^A-Za-z0-9 ]",'',review) for review in bads]
good_cleaned_reviews = [re.sub(r"[^A-Za-z0-9 ]",'',review) for review in goods]

# %% [markdown]
# ### Lets look at our current stop words, and add some of the most common stopwords from the reviews
#
# Because we will be creating n-grams, we are going to err on the side of caution since different combinations of common words may carry large signal, we will also retain numbers to maintain meaning around age of recepients which we know is important from our previous analysis.

# %%
tot_words = []
tot_reviews = []
tot_reviews.extend(bad_cleaned_reviews)
tot_reviews.extend(good_cleaned_reviews)

for review in tot_reviews:
    words = re.sub(r"[^A-Za-z0-9 ]",'',review)
    tot_words.extend(word_tokenize(words))
    
Counter(list(tot_words)).most_common()
# Out:
# [('the', 115938),
#  ('and', 98027),
#  ('a', 75951),
#  ('to', 73296),
#  ('it', 72270),
#  ('I', 64346),
#  ('for', 53980),
#  ('is', 48332),
#  ('of', 43441),
#  ('this', 40375),
#  ('with', 33028),
#  ('my', 31826),
#  ('in', 30397),
#  ('was', 25629),
#  ('that', 21962),
#  ('on', 21758),
#  ('are', 21280),
#  ('The', 19969),
#  ('as', 19187),
#  ('but', 17668),
#  ('you', 17439),
#  ('My', 17253),
#  ('have', 16986),
#  ('so', 16888),
#  ('great', 16559),
#  ('not', 15167),
#  ('them', 14223),
#  ('very', 13838),
#  ('This', 13426),
#  ('one', 12829),
#  ('love', 12807),
#  ('loves', 12795),
#  ('It', 12751),
#  ('they', 12087),
#  ('be', 11742),
#  ('all', 11544),
#  ('old', 11014),
#  ('Great', 10846),
#  ('like', 10228),
#  ('at', 10115),
#  ('these', 9988),
#  ('can', 9813),
#  ('fun', 9726),
#  ('up', 9702),
#  ('little', 9543),
#  ('just', 9493),
#  ('game', 9351),
#  ('well', 8806),
#  ('br', 8786),
#  ('her', 8611),
#  ('has', 8504),
#  ('year', 8458),
#  ('or', 8411),
#  ('good', 8344),
#  ('will', 8302),
#  ('out', 8283),
#  ('kids', 8042),
#  ('had', 7998),
#  ('product', 7914),
#  ('its', 7768),
#  ('get', 7539),
#  ('time', 7517),
#  ('loved', 7480),
#  ('would', 7446),
#  ('when', 7446),
#  ('quality', 7418),
#  ('from', 7417),
#  ('we', 7413),
#  ('really', 7259),
#  ('toy', 7188),
#  ('play', 7029),
#  ('he', 6951),
#  ('more', 6936),
#  ('son', 6710),
#  ('were', 6456),
#  ('daughter', 6396),
#  ('than', 6346),
#  ('she', 6248),
#  ('set', 6111),
#  ('an', 6091),
#  ('We', 6019),
#  ('Very', 5945),
#  ('his', 5828),
#  ('made', 5814),
#  ('cute', 5780),
#  ('much', 5629),
#  ('They', 5532),
#  ('price', 5454),
#  ('what', 5444),
#  ('use', 5409),
#  ('Its', 5393),
#  ('bought', 5331),
#  ('got', 5285),
#  ('if', 5269),
#  ('about', 5211),
#  ('your', 5207),
#  ('perfect', 5198),
#  ('gift', 5075),
#  ('too', 4923),
#  ('our', 4812),
#  ('only', 4808),
#  ('easy', 4792),
#  ('other', 4791),
#  ('nice', 4765),
#  ('even', 4667),
#  ('2', 4553),
#  ('do', 4433),
#  ('some', 4392),
#  ('me', 4390),
#  ('buy', 4345),
#  ('also', 4298),
#  ('no', 4257),
#  ('put', 4159),
#  ('He', 4112),
#  ('birthday', 4093),
#  ('because', 4077),
#  ('which', 4037),
#  ('recommend', 3947),
#  ('She', 3928),
#  ('3', 3904),
#  ('by', 3817),
#  ('off', 3815),
#  ('These', 3770),
#  ('make', 3699),
#  ('dont', 3666),
#  ('any', 3662),
#  ('small', 3614),
#  ('size', 3593),
#  ('box', 3588),
#  ('two', 3561),
#  ('first', 3558),
#  ('their', 3523),
#  ('how', 3499),
#  ('still', 3471),
#  ('there', 3461),
#  ('playing', 3451),
#  ('Love', 3443),
#  ('over', 3428),
#  ('him', 3384),
#  ('Im', 3374),
#  ('together', 3362),
#  ('happy', 3342),
#  ('work', 3325),
#  ('who', 3265),
#  ('back', 3244),
#  ('A', 3161),
#  ('pieces', 3158),
#  ('grandson', 3085),
#  ('came', 3081),
#  ('been', 3080),
#  ('am', 3036),
#  ('So', 3014),
#  ('around', 2997),
#  ('received', 2968),
#  ('did', 2950),
#  ('cards', 2944),
#  ('used', 2913),
#  ('lot', 2908),
#  ('into', 2907),
#  ('now', 2900),
#  ('way', 2863),
#  ('go', 2829),
#  ('i', 2825),
#  ('5', 2804),
#  ('after', 2793),
#  ('item', 2793),
#  ('could', 2765),
#  ('big', 2755),
#  ('4', 2696),
#  ('doll', 2696),
#  ('thing', 2692),
#  ('party', 2684),
#  ('Good', 2670),
#  ('then', 2652),
#  ('expected', 2643),
#  ('new', 2630),
#  ('looks', 2622),
#  ('Perfect', 2567),
#  ('enough', 2565),
#  ('figure', 2556),
#  ('again', 2555),
#  ('different', 2550),
#  ('toys', 2504),
#  ('fit', 2503),
#  ('few', 2479),
#  ('better', 2460),
#  ('purchase', 2459),
#  ('look', 2459),
#  ('If', 2434),
#  ('pretty', 2433),
#  ('does', 2424),
#  ('right', 2411),
#  ('see', 2402),
#  ('didnt', 2392),
#  ('plastic', 2383),
#  ('fast', 2382),
#  ('many', 2381),
#  ('money', 2374),
#  ('best', 2362),
#  ('think', 2340),
#  ('colors', 2322),
#  ('awesome', 2319),
#  ('take', 2211),
#  ('worth', 2210),
#  ('granddaughter', 2208),
#  ('doesnt', 2197),
#  ('looking', 2185),
#  ('child', 2180),
#  ('You', 2174),
#  ('review', 2164),
#  ('long', 2135),
#  ('day', 2128),
#  ('own', 2120),
#  ('years', 2118),
#  ('water', 2095),
#  ('down', 2092),
#  ('comes', 2087),
#  ('want', 2068),
#  ('cant', 2056),
#  ('come', 2050),
#  ('keep', 2045),
#  ('going', 2009),
#  ('need', 2006),
#  ('every', 2006),
#  ('purchased', 1986),
#  ('find', 1983),
#  ('makes', 1979),
#  ('while', 1972),
#  ('each', 1968),
#  ('wanted', 1958),
#  ('arrived', 1944),
#  ('card', 1943),
#  ('Just', 1930),
#  ('bit', 1924),
#  ('favorite', 1913),
#  ('before', 1907),
#  ('sure', 1905),
#  ('know', 1900),
#  ('easily', 1886),
#  ('sturdy', 1866),
#  ('Ive', 1859),
#  ('hours', 1858),
#  ('since', 1848),
#  ('definitely', 1842),
#  ('works', 1834),
#  ('puzzle', 1822),
#  ('say', 1817),
#  ('Not', 1806),
#  ('children', 1803),
#  ('Excellent', 1797),
#  ('same', 1795),
#  ('6', 1794),
#  ('car', 1790),
#  ('absolutely', 1790),
#  ('most', 1789),
#  ('Bought', 1786),
#  ('family', 1785),
#  ('soft', 1763),
#  ('cool', 1755),
#  ('hard', 1741),
#  ('color', 1735),
#  ('super', 1731),
#  ('things', 1722),
#  ('shipping', 1705),
#  ('Awesome', 1700),
#  ('able', 1697),
#  ('though', 1697),
#  ('There', 1696),
#  ('thought', 1696),
#  ('friends', 1692),
#  ('ever', 1682),
#  ('both', 1681),
#  ('another', 1674),
#  ('hit', 1657),
#  ('1', 1644),
#  ('described', 1635),
#  ('far', 1628),
#  ('played', 1623),
#  ('collection', 1621),
#  ('last', 1618),
#  ('using', 1610),
#  ('And', 1609),
#  ('never', 1607),
#  ('something', 1605),
#  ('batteries', 1590),
#  ('actually', 1578),
#  ('without', 1575),
#  ('being', 1565),
#  ('ordered', 1556),
#  ('give', 1555),
#  ('house', 1555),
#  ('piece', 1547),
#  ('But', 1544),
#  ('baby', 1541),
#  ('ones', 1533),
#  ('As', 1533),
#  ('games', 1527),
#  ('exactly', 1525),
#  ('picture', 1512),
#  ('disappointed', 1484),
#  ('always', 1477),
#  ('adorable', 1476),
#  ('Nice', 1471),
#  ('kid', 1448),
#  ('getting', 1431),
#  ('quickly', 1426),
#  ('real', 1410),
#  ('where', 1410),
#  ('Thank', 1409),
#  ('should', 1401),
#  ('people', 1400),
#  ('hold', 1398),
#  ('10', 1398),
#  ('light', 1381),
#  ('durable', 1379),
#  ('amazing', 1374),
#  ('took', 1373),
#  ('battery', 1367),
#  ('cheap', 1357),
#  ('through', 1352),
#  ('condition', 1334),
#  ('beautiful', 1329),
#  ('months', 1328),
#  ('away', 1320),
#  ('order', 1318),
#  ('excellent', 1318),
#  ('perfectly', 1318),
#  ('minutes', 1304),
#  ('All', 1292),
#  ('having', 1292),
#  ('three', 1290),
#  ('kit', 1287),
#  ('Fun', 1285),
#  ('everything', 1283),
#  ('month', 1280),
#  ('high', 1276),
#  ('worked', 1272),
#  ('part', 1267),
#  ('fan', 1264),
#  ('times', 1261),
#  ('pool', 1258),
#  ('parts', 1252),
#  ('top', 1249),
#  ('quite', 1246),
#  ('When', 1237),
#  ('bag', 1232),
#  ('addition', 1219),
#  ('found', 1214),
#  ('days', 1210),
#  ('needed', 1208),
#  ('large', 1207),
#  ('enjoy', 1184),
#  ('daughters', 1180),
#  ('nephew', 1177),
#  ('said', 1174),
#  ('almost', 1171),
#  ('8', 1169),
#  ('excited', 1167),
#  ('Amazon', 1165),
#  ('highly', 1164),
#  ('figures', 1164),
#  ('hands', 1161),
#  ('honest', 1161),
#  ('several', 1150),
#  ('Christmas', 1147),
#  ('buying', 1145),
#  ('No', 1141),
#  ('pleased', 1140),
#  ('once', 1130),
#  ('such', 1130),
#  ('yet', 1129),
#  ('room', 1125),
#  ('help', 1120),
#  ('here', 1116),
#  ('fine', 1111),
#  ('Super', 1101),
#  ('board', 1101),
#  ('sets', 1099),
#  ('sons', 1096),
#  ('inside', 1094),
#  ('already', 1091),
#  ('Our', 1085),
#  ('7', 1084),
#  ('dolls', 1081),
#  ('side', 1068),
#  ('those', 1065),
#  ('us', 1058),
#  ('seems', 1057),
#  ('case', 1056),
#  ('likes', 1056),
#  ('feel', 1049),
#  ('build', 1043),
#  ('girl', 1042),
#  ('broke', 1038),
#  ('plays', 1036),
#  ('extra', 1016),
#  ('making', 1014),
#  ('open', 1012),
#  ('detail', 1009),
#  ('Thanks', 1006),
#  ('anyone', 1004),
#  ('niece', 1004),
#  ('learning', 1001),
#  ('bad', 1000),
#  ('model', 995),
#  ('Kids', 995),
#  ('12', 994),
#  ('paint', 991),
#  ('lots', 990),
#  ('try', 987),
#  ('One', 987),
#  ('place', 985),
#  ('smaller', 980),
#  ('enjoyed', 979),
#  ('delivery', 979),
#  ('wait', 977),
#  ('learn', 976),
#  ('girls', 975),
#  ('store', 969),
#  ('boys', 965),
#  ('thats', 963),
#  ('fly', 962),
#  ('wont', 959),
#  ('couple', 950),
#  ('fits', 950),
#  ('Well', 947),
#  ('version', 945),
#  ('must', 943),
#  ('Got', 942),
#  ('For', 941),
#  ('head', 936),
#  ('What', 935),
#  ('huge', 934),
#  ('exchange', 934),
#  ('went', 933),
#  ('add', 927),
#  ('gets', 926),
#  ('package', 925),
#  ('next', 924),
#  ('hair', 924),
#  ('apart', 917),
#  ('especially', 915),
#  ('youre', 915),
#  ('reviews', 913),
#  ('Easy', 912),
#  ('hand', 907),
#  ('simple', 907),
#  ('deal', 905),
#  ('yr', 902),
#  ('wish', 901),
#  ('turn', 900),
#  ('Cute', 900),
#  ('anything', 899),
#  ('second', 898),
#  ('table', 895),
#  ('night', 880),
#  ('end', 877),
#  ('included', 876),
#  ('design', 876),
#  ('age', 876),
#  ('Would', 872),
#  ('Really', 872),
#  ('instructions', 871),
#  ('balloons', 866),
#  ('ages', 865),
#  ('less', 861),
#  ('Also', 859),
#  ('seller', 855),
#  ('done', 852),
#  ('problem', 852),
#  ('Arrived', 851),
#  ('gave', 849),
#  ('young', 845),
#  ('ball', 842),
#  ('stand', 842),
#  ('LOVE', 842),
#  ('broken', 841),
#  ('may', 841),
#  ('full', 840),
#  ('isnt', 834),
#  ('tried', 833),
#  ('let', 817),
#  ('everyone', 815),
#  ('whole', 812),
#  ('Works', 812),
#  ('others', 811),
#  ('looked', 810),
#  ('costume', 807),
#  ('seen', 806),
#  ('working', 805),
#  ('material', 802),
#  ('face', 800),
#  ('older', 800),
#  ('opened', 800),
#  ('wasnt', 799),
#  ('original', 795),
#  ('quick', 795),
#  ('boy', 792),
#  ('free', 788),
#  ('NOT', 787),
#  ('items', 787),
#  ('value', 787),
#  ('friend', 784),
#  ('Grandson', 782),
#  ('deck', 781),
#  ('read', 780),
#  ('husband', 779),
#  ('dress', 779),
#  ('adults', 778),
#  ('home', 777),
#  ('book', 776),
#  ('wonderful', 773),
#  ('bigger', 772),
#  ('In', 771),
#  ('takes', 771),
#  ('might', 771),
#  ('school', 769),
#  ('probably', 768),
#  ('move', 767),
#  ('waste', 766),
#  ('pack', 765),
#  ('toddler', 765),
#  ('bright', 762),
#  ('lights', 762),
#  ('couldnt', 757),
#  ('LOVES', 756),
#  ('stuff', 755),
#  ('After', 755),
#  ('stay', 754),
#  ('along', 751),
#  ('advertised', 749),
#  ('present', 749),
#  ('return', 748),
#  ('cars', 748),
#  ('started', 747),
#  ('trying', 745),
#  ('nicely', 743),
#  ('liked', 743),
#  ('goes', 734),
#  ('front', 731),
#  ('air', 728),
#  ('building', 727),
#  ('Exactly', 726),
#  ('putting', 725),
#  ('four', 724),
#  ('puzzles', 724),
#  ('until', 721),
#  ('pictures', 712),
#  ('says', 708),
#  ('stickers', 706),
#  ('brand', 705),
#  ('half', 705),
#  ('start', 704),
#  ('Fast', 703),
#  ('break', 699),
#  ('under', 699),
#  ('red', 699),
#  ('show', 699),
#  ('nothing', 697),
#  ('plush', 697),
#  ('Now', 696),
#  ('saw', 695),
#  ('truck', 692),
#  ('Overall', 688),
#  ('tiny', 686),
#  ('wouldnt', 681),
#  ('instead', 678),
#  ('9', 678),
#  ('bottom', 672),
#  ('Even', 665),
#  ('week', 665),
#  ('black', 665),
#  ('Dont', 664),
#  ('strong', 662),
#  ('larger', 661),
#  ('Beautiful', 660),
#  ('stars', 657),
#  ('soon', 657),
#  ('service', 656),
#  ('blue', 655),
#  ('100', 654),
#  ('blocks', 653),
#  ('seem', 651),
#  ('life', 648),
#  ('Highly', 646),
#  ('within', 645),
#  ('held', 645),
#  ('detailed', 644),
#  ('products', 643),
#  ('Was', 642),
#  ('sound', 636),
#  ('idea', 636),
#  ('flying', 633),
#  ('wrong', 631),
#  ('Lego', 630),
#  ('sounds', 630),
#  ('Product', 629),
#  ('glad', 627),
#  ('least', 623),
#  ('white', 623),
#  ('grand', 622),
#  ('balls', 621),
#  ('built', 621),
#  ('20', 620),
#  ('kind', 620),
#  ('difficult', 619),
#  ('itself', 616),
#  ('left', 616),
#  ('wear', 616),
#  ('myself', 616),
#  ('heavy', 614),
#  ('animals', 613),
#  ('players', 612),
#  ('etc', 610),
#  ('keeps', 610),
#  ('extremely', 610),
#  ('job', 607),
#  ('unbiased', 604),
#  ('control', 602),
#  ('gun', 597),
#  ('run', 597),
#  ('Best', 597),
#  ('packaging', 596),
#  ('However', 594),
#  ('clear', 593),
#  ('Looks', 591),
#  ('weeks', 591),
#  ('problems', 591),
#  ('ago', 591),
#  ('characters', 589),
#  ('company', 587),
#  ('fact', 587),
#  ('thanks', 586),
#  ('havent', 586),
#  ('longer', 585),
#  ('Came', 585),
#  ('paper', 585),
#  ('IT', 585),
#  ('assemble', 585),
#  ('during', 583),
#  ('line', 581),
#  ('doing', 580),
#  ('later', 578),
#  ('expensive', 576),
#  ('15', 575),
#  ('motor', 575),
#  ('guy', 575),
#  ('outside', 574),
#  ('adult', 573),
#  ('person', 572),
#  ('recommended', 572),
#  ('feet', 572),
#  ('eyes', 571),
#  ('video', 571),
#  ('either', 569),
#  ('thank', 569),
#  ('Loved', 566),
#  ('shape', 560),
#  ('complete', 559),
#  ('charge', 559),
#  ('wheels', 558),
#  ('course', 558),
#  ('fantastic', 557),
#  ('action', 557),
#  ('fall', 556),
#  ('track', 555),
#  ('completely', 554),
#  ('weight', 554),
#  ('experience', 553),
#  ('someone', 552),
#  ('mine', 551),
#  ('handle', 551),
#  ('Will', 550),
#  ('Id', 550),
#  ('tell', 549),
#  ('train', 547),
#  ('uses', 545),
#  ('satisfied', 545),
#  ('discount', 545),
#  ('else', 543),
#  ('turned', 541),
#  ('blast', 540),
#  ('theyre', 538),
#  ('replacement', 537),
#  ('five', 536),
#  ('details', 534),
#  ('needs', 531),
#  ('watch', 531),
#  ('clean', 531),
#  ('immediately', 530),
#  ('kept', 529),
#  ('hes', 527),
#  ('easier', 527),
#  ('expect', 524),
#  ('summer', 522),
#  ('dice', 518),
#  ('accessories', 518),
#  ('itbr', 517),
#  ('Ill', 517),
#  ('however', 515),
#  ('Granddaughter', 515),
#  ('pictured', 514),
#  ('pull', 514),
#  ('grandsons', 514),
#  ('enjoys', 512),
#  ('button', 511),
#  ('olds', 511),
#  ('pop', 510),
#  ('impressed', 510),
#  ('opinion', 509),
#  ('Definitely', 508),
#  ('solid', 507),
#  ('change', 507),
#  ('plus', 506),
#  ('music', 505),
#  ('sand', 503),
#  ('younger', 502),
#  ('missing', 502),
#  ('amount', 502),
#  ('surprised', 502),
#  ('low', 501),
#  ('lost', 500),
#  ('why', 499),
#  ('hour', 498),
#  ('wants', 498),
#  ('description', 497),
#  ('close', 497),
#  ('stick', 496),
#  ('dog', 494),
#  ('Only', 493),
#  ('sent', 491),
#  ('Lots', 490),
#  ('issues', 489),
#  ('fill', 486),
#  ('stuffed', 486),
#  ('bags', 486),
#  ('receive', 484),
#  ('pink', 484),
#  ('space', 483),
#  ('Everything', 482),
#  ('forward', 482),
#  ('cost', 479),
#  ('variety', 476),
#  ('fell', 474),
#  ('given', 474),
#  ('30', 474),
#  ('power', 473),
#  ('point', 472),
#  ('bed', 472),
#  ('maybe', 471),
#  ('taking', 471),
#  ('arent', 471),
#  ('sit', 470),
#  ('star', 470),
#  ('That', 469),
#  ('fans', 469),
#  ('hat', 468),
#  ('thrilled', 468),
#  ('gifts', 467),
#  ('holds', 466),
#  ('delivered', 466),
#  ('legs', 465),
#  ('player', 464),
#  ('expansion', 463),
#  ('base', 461),
#  ('Amazing', 461),
#  ('remote', 461),
#  ('body', 459),
#  ('today', 458),
#  ('green', 458),
#  ('drone', 457),
#  ('between', 456),
#  ('grandkids', 456),
#  ('animal', 455),
#  ('safe', 455),
#  ('sister', 454),
#  ('display', 454),
#  ('movie', 454),
#  ('cake', 453),
#  ('issue', 452),
#  ('colorful', 452),
#  ('everywhere', 451),
#  ('beach', 451),
#  ('AND', 450),
#  ('slide', 449),
#  ('spent', 449),
#  ('type', 448),
#  ('wood', 445),
#  ('number', 445),
#  ('character', 445),
#  ('packaged', 445),
#  ('holding', 444),
#  ('added', 444),
#  ('Item', 440),
#  ('helps', 439),
#  ('series', 438),
#  ('mind', 437),
#  ('decided', 436),
#  ('Purchased', 436),
#  ('outfit', 436),
#  ('poor', 434),
#  ('push', 434),
#  ('attention', 434),
#  ('Hes', 434),
#  ('shes', 433),
#  ('GREAT', 430),
#  ('pay', 429),
#  ('rather', 428),
#  ('short', 428),
#  ('Adorable', 428),
#  ('Cant', 427),
#  ('THE', 427),
#  ('paid', 426),
#  ('skills', 424),
#  ('pick', 421),
#  ('storage', 420),
#  ('attached', 420),
#  ('tool', 419),
#  ('totally', 417),
#  ('float', 417),
#  ('floor', 415),
#  ('special', 415),
#  ('believe', 412),
#  ('brother', 412),
#  ('group', 410),
#  ('Her', 410),
#  ('filled', 408),
#  ('comfortable', 408),
#  ('busy', 408),
#  ('packs', 407),
#  ('photo', 407),
#  ('With', 406),
#  ('inches', 405),
#  ('parents', 405),
#  ('plenty', 405),
#  ('bubbles', 404),
#  ('Absolutely', 404),
#  ('similar', 404),
#  ('rest', 404),
#  ('stop', 404),
#  ('provided', 403),
#  ('quad', 402),
#  ('cut', 401),
#  ('books', 398),
#  ('holes', 397),
#  ('tall', 397),
#  ('carry', 397),
#  ('grandchildren', 395),
#  ('granddaughters', 395),
#  ('coming', 395),
#  ('rules', 395),
#  ('ready', 393),
#  ('multiple', 393),
#  ('rubber', 391),
#  ('smooth', 391),
#  ('Do', 390),
#  ('regular', 390),
#  ('First', 390),
#  ('cube', 390),
#  ('level', 390),
#  ('feels', 388),
#  ('art', 388),
#  ('Some', 387),
#  ('cheaper', 387),
#  ('glue', 386),
#  ('flimsy', 385),
#  ('flight', 385),
#  ('thin', 385),
#  ('touch', 384),
#  ('simply', 384),
#  ('early', 384),
#  ('sometimes', 383),
#  ('clothes', 382),
#  ('shipped', 382),
#  ('bath', 382),
#  ('designed', 381),
#  ('metal', 381),
#  ('11', 380),
#  ('balloon', 379),
#  ('18', 379),
#  ('unique', 379),
#  ('watching', 379),
#  ('hope', 378),
#  ('backpack', 378),
#  ('At', 378),
#  ('finally', 377),
#  ('entire', 377),
#  ('thick', 374),
#  ('mini', 374),
#  ('directions', 373),
#  ('name', 372),
#  ('spend', 372),
#  ('wife', 372),
#  ('hang', 371),
#  ('actual', 368),
#  ('youll', 368),
#  ('American', 368),
#  ('true', 368),
#  ('THIS', 367),
#  ('Worked', 367),
#  ('slightly', 367),
#  ('mom', 367),
#  ('camera', 366),
#  ('reading', 364),
#  ('High', 364),
#  ('charger', 363),
#  ('fairly', 363),
#  ('ride', 362),
#  ('hot', 361),
#  ('six', 361),
#  ('Halloween', 361),
#  ('challenging', 361),
#  ('Wonderful', 360),
#  ('lasted', 359),
#  ('supposed', 359),
#  ('send', 358),
#  ('bring', 358),
#  ('turns', 358),
#  ('plane', 357),
#  ('often', 357),
#  ('knew', 357),
#  ('single', 356),
#  ('understand', 356),
#  ('care', 356),
#  ('Then', 356),
#  ('His', 356),
#  ('returned', 355),
#  ('gotten', 354),
#  ('realistic', 354),
#  ('Had', 353),
#  ('Barbie', 352),
#  ('stuck', 351),
#  ('Theyre', 351),
#  ('Quality', 351),
#  ('guess', 351),
#  ('project', 351),
#  ('arms', 350),
#  ('Once', 350),
#  ('25', 349),
#  ('purchasing', 349),
#  ('Shes', 349),
#  ('dark', 348),
#  ('bear', 348),
#  ('ended', 347),
#  ('toddlers', 347),
#  ('customer', 347),
#  ('crazy', 346),
#  ('online', 346),
#  ('swing', 345),
#  ('Little', 345),
#  ('due', 344),
#  ('Used', 343),
#  ('match', 343),
#  ('although', 342),
#  ('LOVED', 342),
#  ('themed', 342),
#  ('trip', 341),
#  ('expecting', 341),
#  ('Each', 341),
#  ('features', 341),
#  ('wall', 340),
#  ('leave', 338),
#  ('thinking', 338),
#  ('theres', 338),
#  ('speed', 338),
#  ('overall', 338),
#  ('shown', 335),
#  ('loose', 335),
#  ('throw', 334),
#  ('VERY', 333),
#  ('ship', 333),
#  ('stock', 333),
#  ('remember', 333),
#  ('educational', 333),
#  ('glow', 332),
#  ('range', 332),
#  ('construction', 332),
#  ('asked', 331),
#  ('kitchen', 331),
#  ('giving', 331),
#  ('sized', 331),
#  ('shapes', 331),
#  ('expectations', 330),
#  ('roll', 330),
#  ('straight', 329),
#  ('gives', 329),
#  ('theme', 329),
#  ('future', 328),
#  ('food', 328),
#  ('area', 327),
#  ('junk', 325),
#  ('words', 325),
#  ('replace', 324),
#  ('hole', 323),
#  ('colored', 323),
#  ('wings', 322),
#  ('Daughter', 322),
#  ('past', 321),
#  ('usually', 321),
#  ('mess', 321),
#  ...]

# %%
# we know these products are bought from amazon, lets ditch it
extras = ['Amazon','amazon']

nltk_stopwords=list(set(stopwords.words('english')))
nltk_stopwords.extend(extras)

# %%
def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None

# %% [markdown]
# ### Tokenize, lemmatize, and consolidate concepts
#
#     1. Tokenize the reviews into words
#     2. Tag the word with part of speech
#     3. lemmatize the word using POS calculated before
#     4. Consolidate concepts with regex
#     5. Remove words that are in our stopwords list
#
# **If spellcheck is enabled, cell takes forever youve been warned**

# %% [markdown]
# I am choosing lemmatization since we are not feeding this into any ML models, and since we do not need to worry about overfitting, and lemmatization has the added benefit of being easier to understand for the business analyst who will read our report, since stemmed words are less human-readable

# %%
#part of speech logic stolen from: https://www.programiz.com/python-programming/methods/set/update

def process_documents(tot_reviews, spellcheck=False):
    cleaned_reviews = []
    for review in tot_reviews:
        # Clean punctuation
        clean_review = re.sub(r"[^A-Za-z0-9 ]",'', review)

        # Tokenize into words 
        lemmatized_word = []

        #before tagging part of speech lets run our spellcheck
        if spellcheck: 
            clean_review = spellcheck_word(clean_review)
        else: 
            clean_review = word_tokenize(clean_review)

        #Tag words with part of speech 
        nltk_tagged = nltk.pos_tag(clean_review)  
        wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
        lemmatizer = WordNetLemmatizer()

        # lemetize, use part of speech if available
        for word, tag in wordnet_tagged:
            if tag is None:
                #if there is no available tag, append the token as is
                lemmatized_word.append(word)
            else:        
                #else use the tag to lemmatize the token
                lemmatized_word.append(lemmatizer.lemmatize(word, tag))

        words_clean = []
        for word in lemmatized_word:
            word = re.sub(r"(?:bdays?|birthdays?|b-day?)",'_BIRTHDAY_', word, flags=re.IGNORECASE)
            word = re.sub(r"(?:xmas|x-mas|christmas?)",'_CHRISTAMS_', word, flags=re.IGNORECASE)
            if word in nltk_stopwords:
                continue
            words_clean.append(word)
        cleaned_review = " ".join(words_clean)
        cleaned_reviews.append((cleaned_review))

    return cleaned_reviews

# %%
good_finished_reviews = process_documents(good_cleaned_reviews)
bad_finished_reviews = process_documents(bad_cleaned_reviews)
bad_finished_reviews
# Out:
# ['Do buy They break fast I spin 15 minute end fly dont waste money They make cheap plastic crack Buy poi ball work lot good limit fund',
#  'Showed show Was someone old toy paint',
#  'You need expansion pack 35 want access player aid Factions expansion The base game Alien Frontiers play much smooth add Factions expansion pack All pigeonhole certain path victory',
#  'This gift husband new pool Did receive color I order one month use continuously mesh pull away material inflatable side Completely shred long use It store properly kept outside pool Poorly make good go WM get something clearance',
#  'Received pineapple rather advertised smore',
#  'This much small average size child bounce It size punching balloon VERY DISAPPOINTING',
#  'Dont buy Cheaply make Hippos get stick Cover ball storage attach securely underside game every time pick cover fall ball go everywhere Cant believe game actually pass QC standard You would think 99 cent game',
#  'Not good',
#  'Misrepresentation product per picture I didnt read description closely list item single model however show picture battlegroup include model question Pretty shady ask',
#  'Very difficult inflate The valve design beach ball big recliner Totally disappointed Dont waste money',
#  'These pack overpriced get need pack 35 want access player aid Factions expansion The base game Alien Frontiers play much smooth add Factions expansion pack',
#  'Did get charger one battey',
#  'Terrible product I follow direction 34t34 gun never work Complete waste money zero chance refund DO NOT BUY',
#  'Broke two us',
#  'Sadness My daughter use money work hard earn bubble see tv dont work We barely get bubble leave blower pop instantly Very disappointed Wish could get money back buy toy without false advertising Dont buy Zero star',
#  'Burnt balance trace ruin 4 battery',
#  'Very disappointed Expected 34mega34 set receive tiny set Good 3 yr old',
#  'We buy item daughter play long road trip She never really super interested like regular size magna doodle My husband I try suck Whatever draw last maybe 20 second There need slide bar erase erase Super disappoint',
#  'For price great little loose put',
#  'fail function right box piece crap _BIRTHDAY_ present four year old grandson imagine disappointment face My son doctor even could get operate Send back China Chinese junk buy',
#  'Not I expect',
#  'If I could give zero star I would Partially fault fully comprehend description also product cheap All two break Plus three multiple set Wish I could return son already set eye take back Also NOT FOR CHILDREN Pieces way small ball way hard Just wait one get thrown across room shatter vase',
#  'gift',
#  'buy chair Grandson keep fold Everytime try sit would flip Very poor quality daughter law put outside free sign',
#  'Did help also small',
#  'It NOTHING sit window sill grow mold toy lizard send nothing grow I follow direction closely still nothing Not satisfy',
#  'Wish I would read review purchase The crown make headphone top heavy constantly slip four year old head The sound barely whisper despite audio control max maybe one reviewer mention I get stick flawed product If noise go room forget hear anything headphone I return buying another brand I purchase order work much much good actually stay',
#  'box reset game quality item bad didnt like',
#  'Based description I read price I saw look like big size car I get today tiny size car price u post I saw',
#  'Do order I also fail read fine print review think price 6 one Even order read review hard fine statement get one',
#  'This doesnt function thing advertise There way get leverage bottle opener ear stab hand The keyring come little effort The tiny screwdriver arent large enough screw top mention screw recess 1 cm deep Im huge batman fan love batmerchandise 1000 plus 5 SH worth',
#  'Package say 6 mine open 4',
#  'These fake They flimsy broken break 2nd day Some wont even close My eldest son whole collection real bakugans nothing close quality real one Will return',
#  'Not good play dog Brittle plastic break splinter way easilybr Very disappointed',
#  'Sound work tractor send back refund Thank much refund',
#  'cheap The binoculars break first day everything else end send Goodwill I wouldnt recommend',
#  'Disappointed puzzle The piece oddly shape Would recommend White Mountain Buffalo puzzle',
#  'Absolute garbage poor quality waste money',
#  'come defective',
#  'The item come robin suffer loss limb These fragile toy Ive ever buy Def mean actually play Batmans jacket require hot glue gun right box Ultimately dog eat Theyre dollar store trash',
#  'Balloons fill Shoot empty Dont pop product break try use dont send return intructions Bad product',
#  'Was disappointed game I original enjoy much The Decades version definitely mean young generation It many name musician suit group I play old adult Sorry I waste money I give friend give teenage grandchild',
#  'Pointless waste space home kid desperate get play day get bore The bead dont stick together well Im leave find tiny bead roll furniture Im throw away soon school start',
#  'Amazing These like totally invisible I know I receive packing lkist say box item Couldnt see couldnt feel smell The ultimate hidden treasure',
#  'Small',
#  'This last two hour two wire short one boom fry controller Now I remove everything send test even think replace part The Hobbytown store I buy say bad call manufacturer problem Dont buy Update Firelands send replacement part take hour install still doesnt fly right go trash right Might well throw 100 window We buy Syma X8HG 135 AWESOME Both son old son cheap one without altitude hold love The X8 series start 58 believe MUCH MUCH good quadcopters The Ares JUNK compare Syma',
#  'I receive notice deliverable I want take camping trip try reorder I disappointed I may try future I know fast fun game',
#  'cheap look',
#  'I never get fly Eveything work electric motor would run I call company come want try different procedure try fix About time dog step wing break Probably returnable Kicked dog butt plane go trash Another day paradise',
#  'Arrived broken',
#  'I open Monopoly Zelda edition game tonight And Im play miss Railroads Utility company Bomb Shop Potion shop',
#  'Fell bathtub break within week',
#  'The crayon arrive broken stuff bottom draw It case cloud granddaughter _BIRTHDAY_',
#  'This item could even consider call complete product market Out 2 item receive arrive defective due absolutely absent quality control It would shame present gift fellow chess lover due poor craftsmanship Made poor quality cheap unfinished wood piece first place item worth time hassle go return process Garbage',
#  'Great swing My granddaughter love And perfect fit small people',
#  'Poor quality',
#  'waste time money Buy pair inline skate go skate ring instead way well',
#  'My nearly 3 yr old granddaughter fascinate I think would I read review shop Its turn unused toy',
#  'Omg product waste money period break come make Styrofoam material fragile return item piece garbage',
#  'Light come incredibly frustratingnow tiny useless expensive car',
#  'Low quality price I expect My son blast',
#  'Looks cheap Arrived DIRTY inside wrapping cause concern almost overlook know toddler put hand mouth Everything need assemble',
#  'bad',
#  'Product work leaked water immediately fill',
#  'Really unhappy product The frame car partially break upon arrival This product totally suck Dont waste time buying',
#  'Very tiny didnt even work cake topper Majority eye cross eye look drug Not worth pay',
#  'These dinosaur TERRIBLE The assortment show NOT get Theyre cheap look several ugly bright neon color dinos miss OR get duplicate top wont actually stand guarantee piss kid I go return kid find first 2 standard low But within minute frustrated meltdown fact wont stand didnt 4 leg go trash Which mean 6 So I 6 crappy cheap dinos I cant returnbr Basically dont buy SUCK',
#  'It break 5 minute',
#  'Chintzy',
#  'Way olio expensive Save money get large booster pack price',
#  'These terribly make duster mop fall apart quite easily yarn barely glue place Mellissa Doug PLEASE good I dont know put trash point I try fix possible mean junk landfill use lightly month terrible Parents please keep look something last child use ideally pass others end junk heap Sigh',
#  'These cotton We send back',
#  'Bought dice set assumption new well thats description say The black set blemish green set numerous scuff scratch dull point number 34touch ups34 Dont know make seller Just want customer aware',
#  'My kid love make loom bracelet best quality start break become crack soon put bracelet Almost set sun day upon day take bag make bracelet Absolutely none bracelet keep hr',
#  'stink like spray paint quality design 1',
#  'First flight break Where motor sit break look like glue plus advertise 3 megapix 2',
#  'Dont buy Quality like dollar store stuff Not worth money',
#  'Had reorder product twice still isnt wearable So hat totally worthless piece crap It come bent torn damage first time even bad shape second time Dont even bother hat It even look like hat picture',
#  'It come break pen work Waste money',
#  'Came broken unable repair',
#  'The product picture receive If look exact item purchase The package send us similar piece outfit many accessory We look replace exact item tear try dress tiny little rubbery doll tiny little rubbery clothes exercise patience say least If child young five able alone I dont review item highly general fact I receive different item picture I give single star',
#  'boat great 3 day motor die 5th time pay return refund',
#  'Ok plastic spaceship toddler I look German quality engineering product ridiculous The factory designer make effort whatsoever calibrate design actually worksbr br Issues br 1 The space helmet way stay astronaut sizing sits head like grab close planter near call helmet Trying place astronaut spaceship helmet impossible There enough clearance close cockpit So helmet useless constantly fall cause frustrationbr br 2 Ok issue number one explain oh son need helmet spaceship ok However pilot large cockpit A person really finagle shove guy fit cockpit close Same go get This BS since fundamental point toybr br Dear toy maker let tell 34User Story34 product Three year old use imagination play spaceship astronout adventure For astronout able get spaceship travel location rinse repeat What get frustrate try put together 3 piece outerly poorly design garbage',
#  'Used look good till I go wipe overstay paint wipe',
#  'Working puzzle take forever The piece cut similar small It would good make 750 piece puzzle make piece somewhat different I piece color subject hard many subject puzzle Also piece stick together hard manage I expect quality Sunsout puzzle one fails',
#  'It become DIRTY',
#  'cute look food slip right end narrow Makes great stab food pick',
#  'These feel like solid rock I know look I didnt like',
#  'My son love build Legos etc love Mario KNex system',
#  'Chintzy',
#  'All feather fall everywhere',
#  'Missing hubcap wheel keep fall',
#  'rip look like picture',
#  'The swing doesnt sit straight It tilt forward The guard protection doesnt go far enough get swing Finally lock guard hard open lock place',
#  'This toy HORRIBLE I buy 4 yr old play get frustrated leg fell We would sooner get one leg another two would fall The ant cool legs head wing super glue togetherbr I get glue leg abdomen touch ground Such waste really cool toy',
#  'Only receive one finger hand I want refund 4',
#  'This complete garbage Completely fell apart I take package Dont waste time money',
#  'I disappointed They stay upright Only float side Would recommend',
#  'I receive one year old twin already knock This unsturdy If kid lean side whole thing tip Very upset purchase',
#  'I wish would size description Extremely small Probably choke hazard Do recommend',
#  'There 2 bag miss box We call Lego directly send replacement bag gift disappoint part miss',
#  'Terrible I say I hurry didnt read review wish I It way hard reload shred bullet cheap replace We dozen nerf gun far bad I send back',
#  'The power cord come cut way connect battery power This gift I wasnt able open son return school late anything',
#  'This beautiful puzzle However 6 piece miss The puzzle dark photo package turn make difficult identify piece There also relatively little variation shape piece thatin area pattern use guide see upper leftit easy substitute wrong piece correct one We willing put last two issue give beauty painting puzzle base But find 6 piece short work puzzle week last straw Well stick Ravensburger puzzle',
#  'I dont item',
#  'Finally chance summer rainy day put puzzle together determine miss piece Very disappointed gift neighbor',
#  'DO NOT BUY THIS Extremely cheap plastic sticker come easily Stiff Hard turn My son hat within 10 second open box Them call 34speedcube34 outright lie Its bad turn cube Ive ever see',
#  'The lite come',
#  'These pack overpriced get need pack 35 want access player aid Factions expansion The base game Alien Frontiers play much smooth add Factions expansion pack',
#  'This really good purchase I buy kid play someone el toy harmonica love I think But alas Its big hard play I dont know really play tune I think one I mean buy hohner Sorry kid Usually I like Melissa Doug',
#  'It tough know start I create list When bike arrive huge black rubber tire mark frame would come This mark must storage shipment We return bike think onetime mistake The next bike receive black tire mark frame The rear skewer include package After contact Smart Gear agree send proper rear skewer new frame Smart Gear send wrong replacement frame Smart Gear finally send correct replacement frame Smart Gear send wrong skewer I send bike back refund Smart Gears quality control pretty bad While helpful phone mess twice rectify situation Really abysmal customer service end We purchase another brand balance bike I would avoid debacle steer clear Smart Gear seem perhaps big control thing processedcontrolled A really frustrating experience',
#  'The main bucket break I gotbr It',
#  'lol super price',
#  'Package CLEARLY open four shopkins replace There long hair stick inside package two 34discolored34 character shove spot clearly mold character',
#  'Used tub 3 time Water get never play Sad cute kid love it3x',
#  'The animal cute 2 5 I receive hole leaked air wouldnt stay inflate',
#  'small poor quality',
#  'Seems My daughter receive gift I guess I grateful miss part hair dye go stamper She fun brief moment I dont think play',
#  'This 2025 get buy direct WISH app',
#  'This work doesnt return policy dont waste money buying',
#  'Is typo75300 game cost 2000 less',
#  'Arrived time look great however air pressure need inflate mallet force valve open slowly deflate It fine onetime use would recommend anything',
#  'Yo I receive card today small deck No near 8341134 size list description Really',
#  'No much big To big',
#  'Ball fell apart first day gooey white stuff come',
#  'The game description indicate 6 player necessary make game enjoyable',
#  'Very poorly make',
#  'Sorry review bad quality I want advice anyone dont buy productbr br Best regard',
#  'Not proper brand',
#  'Arrived smash Box good shape product broken Would great minus damage',
#  'Low quality price I expect My son blast',
#  'This BROKE within 10 minute From begin apparent disc A VERY awkward uncomfortable wind especially 7 8 yearold B The disc doesnt go NEARLY far show package B get go far wind tad extra start work OK BREAKS This bad investment toy Ive make long time 13 drain',
#  'Recieved item gift I place another order This item NOT I receive The chair different Not sturdy like previous onestubes much small hold adults62 DO NOT PURCHASE disappoint',
#  'The item would stay inflatted',
#  'Key absolutely nothing Could could key could unclear instruction Not worth buy Heck even worth keep somebody give free Again could I make sense instruction mess key hour I start feel like stupid waste time',
#  'They NOT glow activate Can imagine get ready crush New Orleans baby let Super sad We sad',
#  'Rip',
#  'I receive broken toy',
#  'Item use Singapore',
#  'Broke first time kid use',
#  'The whole set break right away',
#  'I get one 14 dollar instead one 8 dollar gold blood red colour show picture The actual figure NOT colour pale yellow light red colour Should go cheap option The picture deceive',
#  'Terrible material After use less month already mold spot',
#  'It isnt solar power',
#  'Same thing happen previous reviewer No ejection charge whatsoever exact rocketengine Smashed 34Big Daddy34 rocket well',
#  'Still sit pile PEICES way complicate put together',
#  'Hard make bubble',
#  'The damn thing fly away come home button press',
#  'The table chip top receive I dont think worth hassle try return',
#  'lol 115 bux',
#  'I real trouble Bought two themreached seller response The problem leash pop doesnt want stay One board well didnt well husband try glue leash plug wasnt success I wouldnt buy another sad say',
#  'Base bottom hole I cant find fix',
#  'This look like picture I get highly disappointed horn lopsided begin horn oddly shaped almost like chicken leg anything I felt ridiculous wear',
#  'The package arrive time surprisingly fast content expectation There common card 35 card also card Chinese unusable Out card I able use 10 Sorry I purchase even though 50 extra card package',
#  'This knock version James Georges invention tune properly contain proper material likelybr embarrass front audience attempt use fool people You far satisfied original version around price superior quality retraction distance Be warn This knock original artist effect',
#  'I buy pool July didnt get opportunity even take box past weekend When set top ring apparently numerous leak wont even begin hold water I look return policy could return 30 day yes I disappointed',
#  'playground arrive part They tell us contact manufacturer couldnt help us Manufacturer doesnt respond phone call email So 400 worth wood sit backyard Not happy Very poor customer service',
#  'order 2 one didnt work send back worth money',
#  'Very disappointed I specifically ask puppets mouth open tell yes correct There hole arm The sound annoy I return since I need I misinform',
#  'This toy worthless junk It work initially well It NOT least bit durable sink water I really want refund This gift 9 year old grandson huge disappointment I wish I could post star thats possible',
#  'I exact feedback 34Dont get scammed34 I receive ANY stamp show picture I get four package six stamp They say super good job good effort fantastic please correct return This show picture I need classroom I also plan file formal complaint DO NOT BUY THIS PRODUCT unless I describe would like',
#  'This NOT pump I receive A cheaply make version arrive break 2 separate place within hour open package Im dissappointed look suitable replacement I NOT buy product',
#  'C rating accurate Cells balance charge lift 250quad low battery sounder start immediately I try three',
#  'Not good product Eyes dont workI',
#  'It broke get house didnt piece And _BIRTHDAY_ present grandbaby',
#  'These fall apart come unwoven time They also sometimes difficult tighten correctly Not recommended',
#  'Ugh begin Im HUGE fan Ultra Pro Products They thing I use card game card YuGiOh Magic Force Will Pokemon really first year TCG play I hat one product I want double sleeve Standard Size playing card I buy BECAUSE Ultra Pro I wait excited get I try Bow card They tight I bend card try get I buy The KMC Perfect Fit one although quality may feel well KMC one im certain KMC one fit PERFECT card I list I buy 3 pack 3 pack away Dont fool little 34Improved34 insert put sleeve doesnt mean good Trust I try For first time ever I honestly say I buy Ultra pro',
#  'good product handle broke half second day use beach sorry strong shovel',
#  'Leaks place barely blow bubble worth money',
#  'This really work',
#  'Was I expect item small like pot use toddler kitchen small bottle worry child choke',
#  'Very flimsy marble way small young child',
#  'Definitely high quality',
#  'Paid 23 receive wrong itemplanned return emergency state get back son open box This definitely worth 23 Very disappointed able find son flyer want _BIRTHDAY_',
#  'Came broken disappointed',
#  'I buy 4 year old fit The sleeve leg long fit everywhere else fine The costume cute quality poor The cape several run show picture straight package quickly spread make cape look shred If want costume last even look good one wear dont bother Its cute quality worthy one star',
#  'Almost every crayon break wasnt able use',
#  'cube turn',
#  'Do get It work daughter upset _BIRTHDAY_',
#  'I give item one star sole reason return address item VIBRATORS write everyone see This ship work embarrassing',
#  'Is much small appear Need size spec',
#  'cheap never use I saw box worth hassle return donate',
#  'Watched video tiny didnt break hit anyone break hit ground half didnt even inflate Had bunch unhappy kid I buy three pack three bunch Maybe half work',
#  'I happy order thing one pack come 34Extremely hopeless34 pricebr Dollar store qualityMy daughter diappointed',
#  'Broke 3 time',
#  'Balloons keep pop unless inflate useless make anything Very frustrating kid disappointed',
#  'It break time use I dont recommend',
#  'Really hard turn',
#  'It didnt work return',
#  'I excited I saw commercial hope use one lesson kid I work Only one two ozobots work black white anything My fellow teacher I instruction carefully still nothing Even one working follow 34commands 34 Im disappoint I think great product',
#  'Cant see paper trace Returning immediately Even take light pad dark room barely enough light shine enable tracing I guess I get I pay',
#  'Disappointed The bank send without lid I order 5 yr old somethings finish first week school Really want everything perfect little guy Its super cute miss part',
#  'This thing lame It read half story arent even right page My daughter doesnt even look twice Dont waste money',
#  'Second train fail Got replacement today Put wooden floor Ran maybe 5 minute seem operate Now go back forth able move forward Its stick one place There burn smell come fron underneath front train body I product This second train return',
#  'The design glass listing match one I receive I decide keep anyway avoid hassle return I use glass less 2 month already one decal start flake I hand wash immediately dry never use dishwasher since I dont one reason bad quality explain defect Too expensive turn junk week use',
#  'Garbage',
#  'We receive boat within one week battery blow entire electrical system boat go smoke My son plug battery boat continue make beeping sound turn switch entire battery blow smoke fill boat',
#  'We hit one sharp rock first time float river hole big enough put two finger',
#  'Very poor quality price Flimsy plastic small',
#  'Cheaply make The screw hold scissors together come If want reliable quality set try different brand dont buy set Can recommend Boo',
#  'Im disappoint color book look feel like cheap dollar store color book I pay 6 I want try get money back good quality page',
#  'print canvas hard see give try paint painting ask refund',
#  'We get shadow launcher buzz campaign test super easy get package fun However truck barely roll We try hard flooring wheel spin like crazy On carpet didnt much good It cant back either The helicopter fly well first pay fit two day propeller start come away motor take lot figure wrong Now every time want fly make sure propeller push place minute fly require fix',
#  'It two hole wouldnt hold helium',
#  'These disappointment Flat beginning',
#  'What dud My son purchase ran 15 minute work great It work since I contact seller defective toy offer send new one I send defective one back I go ship back find would 20 ship back Great kid would 60 boat hop new one work well Why I get ship back dollar defective After contact seller say I return 25 stock fee The toy defective I would buy product deal seller',
#  'Dont waste money',
#  'Ordered Cookie get Abbey',
#  'wrong battery wont fit',
#  'Not worth money Product description say hand paint The block paint white colored sticker label I could make set less 10 White paint matt finish mean little thing stain Will return',
#  'Very disappointing These inch tall like toy CrackerJack box Not worth even small price',
#  'Received magnifieropened battery compartment realize come battery put battery correct position It immediately heat smoked I let go would burn hand An inferior piece junk sorry I even order',
#  'Product seem 34new unopened34 Package tap back together Product quality poor toy part wouldnt screw together properly Unable use Complete waste money Will never order seller',
#  'Cheap crap Dont buy',
#  'Makes cool noise But tiny Very disappointed size',
#  'Each one fell apart first turn cube Very disappointed quality complete waste money',
#  'When blow top heavy one side Therefore would throw bounce right Its like thickness rubber My kid never play Total waste money',
#  'It look like much good picturebr br 1 color way different red color nearly erase yellow much brighter look like use newbr 2 circle hat bend 4 spot picture barely noticeable',
#  'Pretty bogus Does even split card function',
#  'Was wast money really I buy Legos gift sister 7 year old I get small price big 2x4 block They also come small peices trash I also find chew lego',
#  'All toy come fine bit small microwave would work In order work door completely close push little black button allow start The timer button pretend work thing spin tray light function little button depress inwardbr When come box door latch bend could close try bend correct way end nearly crack door I decide cut latch figure doesnt need latch long door close enough push black button Even without latch door still would close enough work I even let kid push door hard could get work still would unless jam finger press black button I fully prepared take since kid still love I find microwave Walmart half price work properly button usable come work timer Needless say Im happy product',
#  'Got stuckjammed first try work',
#  'My 9 year old barely wrist 5 minute notice rip side grow take I watch put take abusive material Not even good quality rip easily',
#  'Buyer beware I think I order hard plastic doll case 24 inch HIGH future buyer know orderingdo conversion I could buy piece crap Hobby Shop save time trouble order Mybadbr Collection transparent plastic case figure doll case Case W 12 x D 12 x H 24 cm japan import',
#  'We order Soaring Pegasus set package arrive open find package previously open retaped Second set wasnt Pegasus set Cloudsdale set Very disappointed',
#  'So get open seem bit different usual runnier thick soon touch color didnt even stain skin obvious fake yes cheap manic panic im hop come like manic panic anyways doubt wont even stain skin youve use manic panic know stain SO BAD stain skin usually go really good dye im upset waste money fakebr Buy actual site sallys beauty supply stuff suck',
#  'These wing cute fabric tore 2 day dont waste money',
#  'This break one week sevenyearold start use And I dont believe mishandle I wouldnt waste money',
#  'price need low',
#  'Didnt work',
#  'Very disappointed purchase Approximately 2 hr flight time one motor become inoperable obviously prevent flight While price unit reasonable 2 hr use unacceptable Unfortunately due summer vacation miss return deadline Email seller go unanswered Lesson learn',
#  'I look large array color use adukt color book fail notice short pencil However I realize mistake receive I decide keep think really short I small hand figure would perfect I completely wrong These shouldnt even call pencil They short could fit Palm without hang But I since I didnt want waste money I try use They bright want good smooth color color hard That say sharpen 34pencil34 often get good color one sharpen like shard leave Not pencil split 9 10 time lead fell time Needless say I throw away',
#  'My item defective The animal sound play wheel spin know go land Do bother This item small junky person',
#  'Product worth price Im glad I get free bzzz agent I would upset I pay Pictures unrealistic unobtainable',
#  'This _CHRISTAMS_ gift nephew It come box small partially open Balsa wood delicate whoever cram box break Very unhappy',
#  'I Hate This voodoo Doll doesnt even work I hate All hate Dont buy forever',
#  'Product stay inflate 2 us Very disappointing Very small 134 sq patch include Now miss 30day 34return window34',
#  'Not worth buying I purchase grandaughters I take blow local floral department everyone pop fill helium',
#  'My product work Broken arrive',
#  'We excited receive Insect Lore Live Butterfly kit mail We purchase along book butterfly two toddler The kit easy understand well coupon butterfly redemption The issue I ship Hawaii I live pay ship butterfly It write product description I see So get complete kit however I pleased quality butterfly house We end catch bug feed butterfly house',
#  'Broke within hour',
#  'Very dissappointing toy The whole boat fall apart open package It doesnt even float part fall apart water get sink boat',
#  'Do buy Mine come broken The pin fall glue keep',
#  'Over half glow stick didnt glow They able 34cracked34 never glow Thank goodness I order twice much need',
#  'I buy game play grandchildrens age 6 12 instruction play game like take wrench ankle I need pay Extra For The Cards And The Other Bits',
#  'I disappointed quality table The bench bow little weight apply Thank goodness 2 year old weigh 26 lb I really would like return get something sturdy',
#  'After one day play Velcro hold well I think go last long',
#  'Everything cheap easy break small',
#  'Was extremely small',
#  'Came 999 sticker thats worth',
#  'We TONS transformer unfortunately one make cut Poorly make fell apart soon playtime begin',
#  'Broke within 5 minute use',
#  'Buying physical box complete waste money It big box fill literally metaphorically useless bit cardboard sheet toy code The hello world example website complicated first example sheetbr br While website subscription code example may useful I suspect anyone buying feel rip I Check website neat dont buy box hop anything see',
#  'I receive order It look like 34Pig cat34 My 5 year old also notice say 34that doesnt look right34 I try fluff This help Doesnt even curly tail',
#  'It tiny describe opinion Like something would buy dollar tree I waste good money',
#  'This BunchO Balloons product It ship China take two week work The package mark 34Magic Balloons34br br 1 The filler stem fit hose bibbr 2 If figure fix 1 balloon fillbr 3 The balloon fill leak opening fall filler stembr br This totally useless product',
#  'I really excite play mat look closer notice name spell wrong luckily I notice able process refund get different play mat instead everyone look DO NOT BUY IT unless want Asunas name spell wrong',
#  'Showed 16 napkin 8 hat 6 cup Definitely 16 pack describe',
#  'The item describe new item open card money etc bag box',
#  'Grandson already My mistake',
#  'This gift 7 year old boy excited Suddenly family smell burn rubber follow follow smoke This traumatic little guy Really star post one record review',
#  'It didnt come anchor water didnt go way end',
#  'All water balloon leak empty',
#  'Way small worth money',
#  'I order helicopter I love light I get didnt one nose first one I order send back go another sealer tell I look send wrong one',
#  'Bookbag super cute My daughter love After 2 week schoolthe bottom literally fell My daughter 3rd grade wasnt carry large amount book So 2 week school year Im purchasing another bookbag',
#  'These 1000mah I compare size 850 mah battery physical size I cycle get 800mah',
#  'They small cheaply make Im pretty sure even one pair make party still together I didnt expect much still entirely disappointed',
#  'I receive case I receive 6 box I disappointed Had problem get credit remainder box',
#  'Disappointed pool top ring appear defective wont hold air',
#  'Not good quality',
#  'Does amp voice',
#  'No They Crabs Lobsters Pictured absolutely recieve though package labled 34Crabs34',
#  'Being big fan Its Always Sunny In Philadelphia I excite receive product Unfortunately I receive damage conditionWhen I open bobblehead already break 3 piece Sadly I return',
#  'Battery OE Type I return point sure I even get refund I dissatisfied one',
#  'In one day charger come order',
#  'thats charmeleon',
#  'DO NOT WASTE YOUR MONEY I receive mine mail charge battery take spin quadcopter fly great easy operate I buy copter I want shoot cool video first time I try shoot video I remove sd card plug computer I find sd corrupt nothing I use another sd card I know work I use gopro sd also corrupt I return copter next one I get I start fly try take video right away I able shoot video upload onto phone sd card week later I try view video sd card corrupt I try load computer sd card blank THIS PRODUCT IS JUNK',
#  'Is tunebr Can use',
#  'It come yellow substance We try clean put battery The car work siren ALL THE TIME That really annoy So return car',
#  'Please ignore original review This backpack make past first week school strap already tore bag thing notebook empty binder What waste For I pay backpack great deal Bought daughter 7th grade school We receive cant say much durability look pretty sturdy You fit lot largeheavy book hold decent amount Its cute nicely make She love',
#  'It quit work couple use The air pump wouldnt work Very disappointing',
#  'rubber duck tip place water',
#  'Happy 3th _BIRTHDAY_ Nelsito',
#  'I disappointed order I impression would 8 different animal instead get 4 2 different animal turtle crab We want bunch different one I would order something different I know',
#  'Broke within 2 week',
#  'remote control doesnt work since day get',
#  'I get knockoff doll Such crappy product I livid',
#  'Not good Broke use first day Cheap',
#  'This quite possibly bad train set ever designedbr br Due way cart connect completely impossible train go 34slope34 without completely fall apartbr br Also train engine little large curve section trackbr br If love child buy',
#  'Too small 5 year oldwas disappoint It _BIRTHDAY_',
#  'These expensive receive worth price lager item would never cupcake None item pick would stand cupcake',
#  'Breaks first time fall',
#  'I buy trip boy use car They use twice big doodle board break I would recommend item friend',
#  'These Kelly doll shoe They cheap fake knock offs fit Kelly dolls A big waste money If really really work hard sometimes get one shoe onto old model Kelly doll Even danger shoe splitting back come doll They definitely fit new Chelsea come Kelly These poorly make lot left plastic tag shoe would remove quality orient manufacturing process',
#  'So disappointed every one light one light light way DO NOT WASTE YOUR MONEY',
#  'Ordered 3 All show one side already burn Dont bother',
#  'Only 3 12 work short Had return',
#  'I buy fit nerf bow One ruin package Another blue part arrow fall within 5 minute Very disappointing',
#  'We toy son love several month break old child play Our friend buy us new one within one week come apart',
#  'Poorly make game puppie peg would stay car neither would little dog face Its interesting play either way complicate kid even us adults We try desire play',
#  'Received gift The twist handle break normal use leave behind sharp protruding plastic dagger Useless use daughter I call FisherPrice say since make company license would contact directly within 3 day No one ever call',
#  'Overpriced underwritten Please dont waste time It isnt even really fantasy since company try create IP use make race',
#  'This second Puzz 3d Ive built tabs didnt line correctly even I tear apart eye didnt line smile part 7s 1s build head cut correctly several part As many mention tabs bend easily youre stick try make work later The 91 piece list 34easy34 I manage need scissors tape make work Disappointed product',
#  'Found bpa product disappointing',
#  'Pages fell within one day Very poorly make',
#  'Does hold average sized adult Also pay return Not happy customer avoid company future',
#  'Just get mail theres problem safety feature isnt want connect remote',
#  'Over half light waste money',
#  'Cheap bent I recieved',
#  'They wouldnt hold air quite small',
#  'Dont waste money It small worth money',
#  'order July 30 receive Sept 28 The kid SUPER excite The package come 3 attachment balloon black rubber ring hold already assemble No instruction The item one time use unless buy refill pack would VERY time consume However aside ready blast That feeling short live I attach first one hose half balloon would fill The others fell pretty much water The big balloon get 25 inch big I think ok maybe I something wrong As I try put non fill back spout 1015 fill deflated water Imagine disappointment 3 year old We decide give second spout try Same disappointment worse I realize point fun plan activity bust We throw third start craft Uugghh Dont waste money',
#  'Cheap feel barely whistle',
#  'It suck It ship 45 day isnt good',
#  'Wont fit antenna wire thin',
#  'minifigurs bad come gold wepons face discusting',
#  'These waste money opinion',
#  'Bubble solution doesnt come wand solution get everywhere Its good toddler Expensive bubble',
#  'I would give zero star cheap mask For price rip',
#  'Knock versionbr Ive buy pop gun design look one cheap knock version It arrive well package doesnt work string inside long cork break string isnt good one even pop would work would last 5 mintues Im upset 34THIS ITEM IS NOT ELIGIBLE FOR RETURNS34 send break stuff without opportunity refund waste',
#  'This didnt work well It didnt fit onto anything use get water',
#  'Had toy two week one controller button stop work My son love work Poor quality Such shame',
#  'Product didnt include grandma Very disappointing',
#  'If I could give less 1 star I would My son get mower yesterday bubble come unless carpet grass It doesnt get enough traction hard floor bubble get isnt much',
#  'Had return 1 balloon look phallic More appropriate bachlorette party one year old _BIRTHDAY_',
#  'Low quality price I expect My son blast',
#  'One wheel break within 2 minute open toy could repair',
#  'Dont buy child SO MESSY These little bead get everywhere',
#  'The item arrive event I order They EXTREMELY small photo prop I never ever use The item I get use dowel rodswooden stick I use another decoration I create I disappointed item purchase',
#  'Sadly disappointed The box ship wasnt seal It look like open The tassel giant mess kettle part break Also hold 16oz So whoever say get 3 cup flat lie The decorative box also damage I recommend product',
#  'doesnt stay well kept collapse',
#  'Assembly work well The wheel remain loose need constantly tightens',
#  'CROOK br buy pretend make nice block email contact steal money I money back course youre worm revolt know',
#  'daughter want play battery dead I feel buy something come dead battery therefore make kid sad play',
#  'Arrived time like picture Sellers nice work I would happy end Thanks Big Dot',
#  'Not shengshou',
#  'It didnt get kid interest daysplus palydough messy u talk 25 year oldalso hard push green tool I hardly kid',
#  'Smaller size indicated Wasnt able use purpose need',
#  'This impulse buy money waste basically piece junk dont waste money buy couple lottery ticket insteadbr Edit 101615 clarify reviewbr simply good product hard mount smartphone I also worry scratch damage expensive phone doesnt work well I use smart tool app android function superior way attachment need risk damage phonebr So yes save money buy lottery ticket anything',
#  'Used n leak side Very disappointed',
#  'Disappointed I receive 5 shopkins',
#  'I buy wagon almost 12 grand I extremely disappointed It kid red wagon For price I expect jet propulsion time machine least DVD player That last time I spend penny 1000000 wagon',
#  'These balloon keep pop face Id blow After 20 I throw away would scare heck time',
#  'The package come piece list product info I receive charge cord extra blades The product useless without proper charge cord include',
#  'The tag say retail price 5 Enough say',
#  'break moment open',
#  'The bottom rip easily baby fall DO NOT BUY This product name one TOP 10 MOST DANGEROUS TOYS The company make ignore problem rename company continue sell dangerous product Ive see several YouTube video Im absolutely horrify lack moral concern customer PLEASE DONT BUY THIS DANGEROUS TOY',
#  'Bad material Buy one different user theyre much well',
#  'This gun rename 34darteater34 jam constantly shred dart process',
#  'I buy event hop bring water balloon Instructions state balloon 34immediate use only34 Only hour two fill balloon empty The rubber ring close balloon simply tight enough keep water balloon significant period time Complete waste money case Probably fine neighborhood water balloon fight use balloon right away',
#  'MISSING HELMET AND TOY GUN son upset Not nice think would Cheaply make Misleading',
#  'After I hit come home button drone turn away fly away Other seem like cool toy first 10 minute',
#  'Cheap Terrible plastic fabric Bad stitch Poor design Was excite never purchase',
#  'Awful product nothing like photo size poor quality material',
#  'Arrived DOA',
#  'Charging contact Bad',
#  'Sounds like good idea But I buy two neither one work hide n seek monkey',
#  'doesnt work waste money',
#  'Not I expect Thought one box To expensive little toy',
#  'Does look like picture also small',
#  'Very flimpsy 3D product glass actually plastic Waste moneyTalk get wgat paided',
#  'piece crap',
#  'SUPER TINY This thing look like toy come claw machine It much small look picture',
#  'bad quality small hard finger insert look like picture',
#  'Very disappointed Got completely different toy look veey use Hoping get money back',
#  'disappointed glow last minute',
#  'This come I shock 4x6 inch box I go buy another gift give grandson I keep small _CHRISTAMS_ present',
#  'Husband say hard throw get wet',
#  'This sky Hawkeye hm1315sbr These piece garbage dont work seller want sell dont care drone dont work dont care try reach waste money',
#  'Came broken disappointing',
#  'This bad thing see pay new thing get use onebr When open box way pack look like use soon fill air I saw grass come itbr I fill air night last long till morningbr br I start return process itbr br My son like hence reorder hopefully get something good',
#  'Most Helpful Customer Reviewsbr br Painfully Cruel Those Living Caring Mental Illnessbr By Gayle August 30 2015br Size One SizeColor Orangebr I write share serious matter importance relate costumebr My younger daughter honor student athlete musician illness present onset adolescence live schizoaffective disorder past six year hospitalize child Weve take UCLA Stanford well local hospital hop make sense devastate illness If ever spend anytime visit loved one mental health treatment facility I assure would understand costume painfully cruelbr Human suffering appropriate inspiration Halloween costume I doubt would sell Stage Four Cancer Holocaust Slave costume Why would sell costume make fun severe brain disorderbr Stigma encourage hopelessness despair Please reconsider stigmatize daughter real illness removingbr costume mental illness inspire costume inventory',
#  'Product description photo misleading Stars 34black shadow34 rather 34spec light34br Product quality expect',
#  'It wasnt model clay advertise Its like play dough Wish I could return get money back buy actual modeling clay son',
#  'Dont seduce price These badly make Its annoying animal stand leg turn inward Its annoy tree fence dont stand But real reason buy theyre simply safe small child paint sticky peel expose glue seamsbr br If purchase three option Option one Give kid bucket terrible toy sticky peel paint glue gob Option two deal bother return Option three throw away We choose option two',
#  'Not I look Very disappointed',
#  'One floatie didnt even inflate The one fine I didnt two work floaties obviously didnt get use pool Not buy company wouldnt recommend Just worth effort return',
#  'These crayon strong even toxic odor I feel confident allow child use',
#  'Unfortunately product never work unable use tick n tater I suggest spend money product',
#  'The paint mess animal magnet dont go letter Theres ladybug letter W instance',
#  'Okay expensive',
#  'Product defective The noise maker break It would really great gift star war nerd hubby Id work Missed return date',
#  'It disappoint thin light small I expect big earring price still photo imply',
#  'Barely flew Didnt make sound',
#  'My son like picture tattoo didnt even last 12 hour',
#  'Got car son May 2015 A part hold suspension break first drive I replace part three time already seem break every time drive I buy extra part Then suspension brokehave replace itnow car doesnt move look like transmission engages run wheel run I hold air Just think whether I fix itsince spent I buy car Just disappoint quality When I see video website I wonder run much without break Would recommend Litehawk',
#  'Perhaps price include roundtrip first class ticket Japan pick ship charge doesnt make sense',
#  'Article I arrive I use scrapedbr Im disappointedbr Great ship Very fast',
#  'Unhappy purchase Product assemble exactly instruct Extremely unbalanced constantly tip Should easy maneuver difficult neither boy use though lack try Ages 4 7',
#  'Do purchase band use seal balloon fill work water pour Spend extra money see tv balloon',
#  'This broke first time use',
#  'Can get dough mold Completely useless',
#  'People warn however decide try outmaybe would work monthbut thats truejust one day',
#  'I screw hold purple piece hold shutter place start pop son play hes 11 month wasnt rough I end take piece I afraid screw pop would choke hazard I also try push screw back always pop back like plastic screw go strip',
#  'Havent actually use yet bearing almost lock I open package use penetrate oil get well I doubt theyll ever smooth enough actually balance anything Also get Helimax version order much well quality',
#  'half marker arrive already dry outwhat bummer',
#  'I never see card whole deck doingthe front card separate back Not one card nine far When first one start come apart I scotch tap Then started separate They use four adult rough handling These card pricey happen',
#  'Not happy water ball dont shoot well',
#  'The bat bottom part miss original shipment replacement shipment well',
#  'It easy operate terrible sound quality Could use',
#  'This item GARBAGE The kitchen come 15 miss piece take 4 hour assemble I call 5 time part send rude staff keep put hold Do NOT waste time money crap',
#  'It turn broken',
#  'Product arrive rear wheel assembly broken beyond repair The part 32 SPST8550N shatter cause drive axle swing around freely mar rest frame The nondrive rear wheel one wheel actually connect securely enough axle drive loose axle apparently cause one retain washer break As warning user assembly use look prone breakage 1434 plastic retains large 2534 diameter mold plastic splitwasher attach axle If portion cast plastic washer develop crack fail tip tractor axle swing freebr br Its good thing I didnt even let boy see let alone ride would crush take away seriously hurt try ride Im glad I catch within return window read review tractor small sound look like tractor isnt boy',
#  'Do buy Wings fall engine fall Cheapest make crap Sad item',
#  'Shocked quality price disappointed I expect',
#  'Im sorry I didnt go post office',
#  'The part fit properly The plastic piece bulky cheaply make I disappointed',
#  'The color impressive however consistency paint smear didnt paint The result like try paint wax paper The box paint total discard isnt usable anything When even infant find useless know problembr br Perhaps batch defective Im puzzle good review This unusable',
#  'HORRIBLE PRODUCT The balloon fill quickly seal cause water leak render useless Which terrible inconvenience flock teenager excite ready water balloon fight DO NOT BUY THIS PRODUCT',
#  'Didnt like',
#  'Your image show harvester ant specie',
#  'It hole didnt get use I dont feel I pay ship back',
#  'Very disappointed This pool brokeleaked several area first use',
# ...
#  'The picture description say game box pic look like come assemble box game 8 baggies unassembled Was real disappointment',
#  'The cup short original tin make way tooooooo much noise able stand use reason I buy I want one match one I already original Now go back order two cup well Would return box take trash waste recycle truck I know noisy cup',
#  'Junkdoesnt hold air',
#  'This thing essentially crap I guess get pay forbr The wax suck thread end cut wax easily try carry something heavy The thread hand piece sht Its bouncy twisty object end thread curl instead stay straightbr br DO NOT BUY WASTE OF MONEY',
#  'They good quality LEGOThese cheap knockoff',
#  'Cheap knockoffNot good real LEGO',
#  'Bought discount I dont think worth price Limited function game play Touch screen responsive Save money get well high tech toy kid',
#  'Im therapist client like stress ball This one get mail totally flat Total waste money',
#  'My 5yearold son absolutely love arrive He laugh laugh laugh Almost immediately though opening start split By end first day split much longer useable Bummer',
#  'Bags OK recieved cheap rubber band instead pencil Change product offering deliver advertise',
#  'I high hope product Every LeapFrog product I ever get great addition granddaughter life The tablet wonderful way learn stay entertain long car ride But Its confusing way easily break Now clarify Im talk reader pen book The book fine But pen take long set even doesnt work Im disappoint product Do favor go buy cheap early reader book read',
#  'These jumbo The card I rexeived 6x4 inch huge one photo',
#  'A lot short I think',
#  'It break within 15 minute play Motor partially function one two rechargeable battery dead',
#  'Doesnt even deserve one star Purchased son third _BIRTHDAY_ stop work properly within hour Poor design bubble tray big problem start button review mention Wont stay stay turn wont turn Almost equally problematic design wheel much small We already toy mower step2 son love bubble much get While mower large sturdy wheel wheel flimsy light small make almost impossible push anything paved surface ie turn blow bubble cant even push grass We purchase another cheap mower different brand maybe Fischer price infinitely well quality design nice large heavy wheel make easy push grass I didnt return time I didnt want son give new _BIRTHDAY_ present excited one else waste time money toy junk',
#  'The description toy 6 inch whereas actual toy 910 inch Im disappoint would lie My son want Thor toy small size action figure one giant',
#  'Never receive product promise refund Lame',
#  'This way small I saw airport And material soft smooth Not well make',
#  'Less week stop work Returned',
#  'Very small fragile It break piece second day son play Very disappointing',
#  'Item badly damage take long time arrive',
#  'The little biplane seem perfect drill use take apart put together plane fail The forward gear work ONE time work longer Only backward gear work result disappointed 3year old thoroughly chap grandmother',
#  'This replacement old My Pal one personalize name My daughter 7 Scout since year old want new one sleep every night The new ScoutViolet huge disappointment LeapFrog realize screw 34new34 version I guess money go advertisement ear instead',
#  'Unless live flat perfectly clean concrete DO NOT BUY It tip lose bubble PITA parent deal two year old',
#  'We give child 6 hour get break The metal hinge door fell wheel fell Not design toddler rigid easily break Going throw away semi truck keep match car actually good quality',
#  'Okay I order two show number card kind deck get order include card 5ds zexal whatever I cant say card arent decent I want nostalgic purpose If like order Not one card original series And maybe unlucky I get 100 card single one original series If like series feel free buy otherwise dont',
#  'Not expecyed',
#  'No Stars This break within first week come horrible smell wouldnt go away Awful purchase',
#  'Very poorly make different picture Top material itchy cause daughter get rash wear less 5 minute Dont waste money',
#  'Price pay 2800 price box 199overpriced',
#  'This amazing look rifle leave 6 year old speechless walk store Needless say 34had34 buy _BIRTHDAY_ He less hour action 34clip34 jammed chew dart First Hasbro magazine clip Second dart really loose magazine fall alignment easily Third need remove magazine reload unjam throw wall frustration even I adult difficulty remove The caliber dart seem perfect barrel small magazine bolt fee DO NOT BUY THIS RIFLE FOR YOUR KID UNLESS YOURE A PLASTIC GUNSMITH Ive take apart less 3 time first week remove chew ammo',
#  'Very upset clearly show two stamp I order 2 set receive 2 stamp total',
#  'GARBAGE Was even worth give son It go straight trash bin',
#  'Not appear',
#  'Werent I think Too small',
#  'Disappointing hype price Dont buy My sixyear old granddaughter much LEGOs Rokenbok building toy never get interested Roominate probably difficult put together fall apart easily assembled doesnt make furniture fun play doll bunny toy Waste money I excited give something special',
#  'I buy dress sister It say 34hand made34 plastic dress didnt even look nice I guess I see many good review Im disappointed',
#  'Broke key chain first week',
#  'Pieces break didnt fit right',
#  'I heed warning size stoarage case It fit ONLY 2 5 MD puzzle worth money The puzzle fit small peg puzzle large puzzle fit go sideways puzzle stick',
#  'We purchase 2 good experience While pump 1 way pool break plastic inside part The one break within 5 min use The plastic almost part',
#  'Quality awful Pieces warp stay together Do waste money',
#  'Only 2 balloon packet usable The big tent ballon three print damage I end buy balloon store Waste money Associate party city say style discontinue reason',
#  'Packaging impossible take scissors knife lot muscle get everything box Then didnt really work Taking back today',
#  'pretend make 5 year old find bore',
#  'Please remove trash site',
#  'The product state 3 piece I receive one Will return Really disappoint since mean party favor son pool _BIRTHDAY_ party tomorrow',
#  'TOTAL WASTE OF MONEY My granddaughter get Olaf paint come approximately 1 hourbr Apart order note receive 1 character small look like get whole set br Even get whole set still would total waste money',
#  'Oh My God Have read term 34When upload submit store send receive content Services give Google work worldwide license use host store reproduce modify create derivative work result translation adaptation change make content work well Services communicate publish publicly perform publicly display distribute content34',
#  'ugh didnt realize old fashion kind blow But cant even rubber stick together Plus powder get everywhere Save money Go dollar store get kind dont ask much',
#  'Junk',
#  'When get piece brokenThis come house',
#  'There three miss piece I disappointed child I think I could always trust Melissa Doug product unacceptable quality control',
#  'Too cheap son 5 minute break drop handle blade separate',
#  'Worst neck pillow ever Its flat Theres fluff ever Dont waist money',
#  'Go play Heroscape This bad Heroscape',
#  'Cheap knockoffNot good real LEGO',
#  'Not sure engineering skills 5yr old daughter suppose learn build besides learn fold paper Once together ball take two second go thru maze She bore 2 try Dont waste money cheap make china junk Buy Legos instead If kid doesnt like Legos least resell close pay',
#  'Poor safety delivery come break I need replace information',
#  'SES Creative Childrens Super Clay much well This molded didnt last long',
#  '2nd bad thing buy co volacano slap reactive ingredient together slowly ooze 34volacano34 crap worth price would good make volcano old fashioned way use baking soda vinegarbr buy 60 mechaics kit pulley gearscant remember name overly complex part dont fit together instruct miss I mechaical experience fun My grandson disappoointed buy lego',
#  'I order two cat money bank exactly picture I receive wrong one plain orange cat I dont understand cat say But definitely 34Meowww34 disappointed',
#  'Wish theyd sample picture inside book Not I want two half year old I want paint inside picture strip along top Waste money age group',
#  'extremely poor quality Product information say 34colorful34 however stamp solid red Almost half stamp set far holder therefore touch paper attempt stamp This definitely poor use 10 would recommend anyone I could give 0 star I would',
#  'Cheap knockoffNot good real LEGO',
#  'This complete crap To start suppose come 50 card come 25 Next card well use definitely mint There also single card galactic overlord total scam I also get several duplicate card I get common Never buy item total rip would good buy 3 4 single card instead',
#  'Bad Send break product',
#  'Sorry dont buy good deal Thats I say',
#  'awful toy small part stay together work',
#  'Looked cheap Some broken Didnt work',
#  'I excited I receive product I get light work They turn second shut right back Brand new battery I wish I could get work really disappointed',
#  'Cheap knockoffNot good real LEGO',
#  'Very cute last day two',
#  'I use mine 5 time Premo clay break First brass screw break away chrome piece pain still usable brass screw piece strip It also difficult crank Premo clay Im sure work great something soft fondant I wont',
#  'I really hate They break fast',
#  'In word cheap Inexpensive point stick bend nearly half weght plate Due packaging far small plate stick shape I would never purchase another thing company',
#  'Air Hogs Smash Bots worth money My 9 year old play less day sit around collect dust First negative need 10 AAA battery make trip store could even get start The game board really thin flimsy play hard surface Overall lot variety toy The excitement fun fade really fast There much good choice child price range I ask 9 year old felt one star fair rating say yes',
#  'PLEASE DONT BUY THIS I WASTED MY MONEY ON THIS dont Also even loud doesnt work phone people growl call',
#  'throw money away total trashi two neither work right boxproblem defective motorsamazon USA Toyz great replace first one refund money second oneUSA Toyz send two replacement motor one workedBottom line UDI 818AHD Quadcopter defective item company make poor quality control',
#  'Wouldnt recommend due poor construction We purchase item inflate shortly get maybe day later deflate Inflation last day youre stick huge worthless piece plastic floating pool',
#  'The product stop fly mid air break first time fly I wasnt near tree power line antenna propeller get tangle less five minute I feel cheated would like replace',
#  'Used casually pool 4th use rc boat filledl water long work Weve go numerous RC boat thing happen every time',
#  'Was size I expect Useless worth return',
#  'Cheap knockoffNot good real LEGO',
#  'If order make sure build right awaymissing several piece since open return time way trash',
#  'Cheap knockoffNot good real LEGO',
#  'The letter small stick sheet individual like picture',
#  'It say glow dark doesnt zero glow Look video youtube',
#  'The item I get serious quality issue First head separate several part first place I carefully connect together complicated work But beginning I also figure tail connect body articulation basically wrong The hold use articulate way small impossible connect tail Moreover articulation easy detach especially toe When I try adjust post detach It uncommon The quality suppose terrible Therefore I conclude faulty product Ironically seller AmazonCom I dont know purpose Because I get 10 dollar cheap current price',
#  'Would buy They leak didnt fill full',
#  'Gave 2 year old son _BIRTHDAY_ love Very sturdy like picture ship quickly Very happy product',
#  'Product arrive yesterday Perhaps heat delivery product somehow melt It smell like bathroom sound like Doesnt make noise well horribly stinky Im incline throw away I regret get',
#  'The plug blow stay plug pop open deflate constantly Will need put duct tape something keep close',
#  'toy want',
#  'break within two day Just crack stop work',
#  'Bought whim niecewho petite side wasnt able use glove The finger long narrowhorrible fit The bracelet list wordingso photo I didnt notice include wording get terribly disappointed keep ask bracelet The ring cheap glove material cheapthe purse okay I guessbut I expect Disney item Wouldnt recommendand I 3 daughter wont buy either Not happy',
#  'Floats great Top rod snap light breeze Dont waste money',
#  'Pulled tag didnt light',
#  'magnetic',
#  'I dont know valid review Jiraiya The picture Gaara That two completely different character So question Gaara Jiraiya scam',
#  'poor design easily bent',
#  'I excited toy After 4 week break right half We keep inside rain 5 year old play outside dirt sand I email company nice provide new one Two month receive new one one break half well The link connect two part weak good outdoor toy',
#  'The top bobble around doesnt stay Plus star often slip sensor without set light sound defeat purpose buy traditional version',
#  'Did work',
#  'didnt come color show photo We get ugly color work 1st _BIRTHDAY_ party',
#  'This product break within minute use waste time I would argue purchase product',
#  'It didnt work',
#  'One size fit didnt apply 3 yr old shoe size 910 I pull strap way pass hole still big big gap heel end shoe She able walk I would return want charge return fee restock fee Maybe able wear 56 Hopefully still Belle',
#  'I receive 3 item receive one',
#  'No boxhad original plastic box highly dissatisfy especially since list new',
#  'Warehouse ship toy poorly break nonfunctional Looked like nice piano newborn 12 month old',
#  'Does work even small child',
#  'Make sure save cardboard tube wrinkled mess piece dont stick mat',
#  'Was disappoint We think chalk PENS glass actual chalk shape like pen Oh well Fancy sidewalk chalk',
#  'Overrated virtually impossible use',
#  'Cheap knockoffNot good real LEGO',
#  'Cheap knockoffNot good real LEGO',
#  'Cheap knockoffNot good real LEGO',
#  'Will fit H107C The hole small motor',
#  'Cheap big enough Dont bother big size 4 boob big small B cup',
#  'This waste money dont work Fits really loose want stay Im disappointed great idea work would even great',
#  'This bad toy I ever purchase My 7 year old son want set badly First Ill start instruction shall I say lack instruction They take lesson Lego They know write direction This set 7 I 45 yr old woman pretty good build set I frustrated put together 30 minute I put back box husband build My son wait 2 day time work He construction even frustrate put together After hour figure many piece miss couldnt even finish I dont mean 1 2 piece miss even 56 matter Also Zombies suppose stand I would call Lego type brick They would stay brick They keep pop one actually able get half second Worst toy ever I disappointed 7 year old 2 seriously irritated parent What huge waste money If I could give negative star I would',
#  'meh',
#  'The item look nothing like picture',
#  'Didnt even get ground Didnt even get house Motor smoke preflight testbr Using 111V 3S LiPO motor ESC purchase During servo test battery plug appeared fine Motor spinning flap rudder check Then poof Cant believe ruined flight day Major let downbr Might file claim try return even go bother 3',
#  'These baton poor quality unusable I throw awaybr I buy baton much good quality',
#  'Cant get stay stand',
#  'It didnt meet expectation The cube fell apart within week Its easy put back together wont stay together Will purchase another I guess I get I pay',
#  'The seal blow first time blow',
#  'Its really poor quality frog look uneven',
#  'Let tell mask STUNK Literally It smell like rubber poo time It terrible air MONTHS still stink even We stuff newspaper human head enough give proper head shape The body suit fine part come though I think anyone look buy item take review consideration since accessory miss sometimes I think might smart look elsewhere',
#  'This item arrive break Plus isnt 28 1 case like description say It hold 24 include two SD holder So really hold 22 game',
#  ...]

# %% [markdown]
# ### Deciding on number of N-Grams
#
# Both 2, 3, and 4 are common choices for n-grams, I am leaning toward higher counts since we want to deliver our final report to a business stakeholder, lets run both and we can compare outputs down the road, its worth noting that 3 ngram will have many more vectors which may bea  definite downside.

# %% [markdown]
# Looking at these results we can see that 4 grams produced the most insightful features, we will use this number moving forward

# %% [markdown]
# ### TF-IDF Report

# %% [markdown]
# By looking at n-grams without numbers we are able to consolidate "my x year old" type statements which creates a more accurate and succienct analysis.
#
# We performed an TF-IDF analysis in order to answer the following questions:
#
#     1. Features that drive good reviews
#     2. Features that drive poor  reviews
#     3. the most common issues that generated customer dissatisfaction.

# %% [markdown]
# #### Features that drive Good reviews
#     bought this for my	552.572127
#
#     Top 7 features from our 4-6 n-gram vectorizer are:
#
# | N-Gram      | Score  |
# | ----------- | ----------- |
# | bought this for my      | 552       |
# | for my year old   | 461        |
# | my son loves it | 416 |
# | in exchange for my | 304 |
# | my daughter loves it | 302 |
# | exchange for my honest | 277 |
# | my year old loves |	277 |
#
# </br> </br>
# </br> </br>
#
#
# The most important phrases from our TF-IDF analysis for positive reviews can be grouped into 3 main "concepts" or collocated phrases, groomed from across 3 to 6 ngram results for the most insightful features that are still human readable
#
#     1. Reviewer was given a benefit in exchange for a reivew, such as a discount
#         - "discount in exchange for my honest"
#         - "honest and unbiased review"
#
#     2. Item was a gift and recepient was pleased with item
#         - "my son loves it"
#         - "for my year old"
#
#     3. Actual Features of the product or service
#         - "arrived on time"
#         - "easy to put together"

# %%
vectorizer = TfidfVectorizer(ngram_range=(3, 4),
                             max_features=500, max_df = .8)
X = vectorizer.fit_transform(good_cleaned_reviews)
terms = vectorizer.get_feature_names()

tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)

score = pd.DataFrame(tf_idf, columns=["score"])
score.sort_values(by="score", ascending=False, inplace=True)
score.head(50)
# Out:
#                             score
# my year old           1060.143115
# my son loves           783.140400
# my daughter loves      713.726869
# for the price          634.414076
# this for my            622.111232
# to play with           609.354407
# bought this for        542.959091
# this is great          529.088319
# kids love it           474.385197
# daughter loves it      446.607244
# so much fun            436.605627
# one of the             435.161195
# this is the            431.501060
# son loves it           401.327699
# very happy with        383.655306
# gift for my            380.724792
# bought this for my     374.651432
# she loves it           369.367708
# well made and          357.183245
# lots of fun            356.886410
# perfect for my         350.088261
# he loves it            348.949795
# love this game         332.735670
# for my year            324.323288
# grandson loves it      322.028873
# my grandson loves      321.624539
# lot of fun             318.674919
# my kids love           311.843082
# out of the             308.303540
# and it is              305.682252
# arrived on time        305.381768
# year old loves         300.833783
# for my year old        299.090038
# got this for           296.003716
# to put together        286.831509
# and it was             286.703365
# my son loves it        285.826309
# and easy to            285.807868
# playing with it        285.417474
# for my son             283.068262
# very well made         280.312311
# exactly as described   278.157894
# cant wait to           271.405303
# if you are             269.021265
# as well as             268.124377
# daughter loves this    267.143395
# all of the             266.527274
# she loved it           265.469384
# great addition to      265.378824
# on time and            263.811939

# %%
vectorizer = TfidfVectorizer(ngram_range=(3, 3),
                             max_features=500, max_df = .8)
X = vectorizer.fit_transform(good_cleaned_reviews)
terms = vectorizer.get_feature_names()

tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)

score = pd.DataFrame(tf_idf, columns=["score"])
score.sort_values(by="score", ascending=False, inplace=True)
score.head(50)
# Out:
#                             score
# my year old           1145.890122
# my son loves           828.266182
# my daughter loves      790.164770
# this for my            689.560817
# for the price          627.453720
# to play with           610.856129
# bought this for        586.068913
# this is great          519.534170
# kids love it           503.941592
# daughter loves it      502.487050
# son loves it           462.684476
# one of the             457.790083
# so much fun            439.910376
# this is the            422.939357
# very happy with        400.343033
# gift for my            393.305809
# she loves it           386.543395
# for my year            377.156971
# he loves it            367.892182
# year old loves         356.480169
# lots of fun            355.242226
# well made and          353.706076
# grandson loves it      351.412590
# my grandson loves      347.123471
# perfect for my         345.668932
# love this game         328.241497
# arrived on time        328.039165
# got this for           321.675875
# out of the             316.271276
# lot of fun             313.888905
# my kids love           311.084411
# daughter loves this    308.090919
# to put together        304.814525
# and it is              302.125907
# son loves this         288.213416
# on time and            287.391961
# and it was             287.246520
# for my son             284.940457
# and easy to            284.365409
# playing with it        280.675415
# very well made         279.201015
# exactly as described   278.474858
# my son loved           276.106911
# she loved it           275.559649
# cant wait to           269.258168
# year old grandson      265.512885
# as well as             265.073736
# great addition to      264.050742
# if you are             263.594155
# all of the             263.266767

# %%
vectorizer = TfidfVectorizer(ngram_range=(4, 6),
                             max_features=500, max_df = .8)
X = vectorizer.fit_transform(good_cleaned_reviews)
terms = vectorizer.get_feature_names()

tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)

score = pd.DataFrame(tf_idf, columns=["score"])
score.sort_values(by="score", ascending=False, inplace=True)
score.head(50)
# Out:
#                                 score
# bought this for my         552.572127
# my son loves it            461.160128
# my daughter loves it       416.263511
# for my year old            402.806434
# my son loves this          304.527816
# my daughter loves this     302.138022
# got this for my            277.788459
# my year old loves          224.438965
# easy to put together       220.357903
# my grandson loves it       212.367835
# one of the best            190.794663
# my son loved it            188.226086
# and he loves it            185.321930
# and she loves it           176.271459
# bought it for my           163.333705
# my daughter loved it       162.396249
# year old loves it          159.460128
# my year old son            159.397988
# my year old daughter       158.200258
# arrived on time and        155.057260
# my year old grandson       154.702238
# out of the box             151.266484
# very happy with this       147.751060
# my granddaughter loves it  147.051542
# my two year old            145.093884
# what was looking for       143.359777
# bought these for my        141.863067
# fun to play with           141.793475
# to play with it            137.661424
# my kids love it            137.502157
# the quality of the         137.351840
# at the same time           137.149935
# this is one of             137.105871
# as gift for my             133.998141
# one of my favorite         131.905790
# the kids love it           130.842983
# in exchange for my         128.285435
# and she loved it           124.880074
# my granddaughter loved it  124.398638
# this is the best           119.154814
# the perfect size for       118.497663
# is one of the              118.268752
# it all the time            114.487564
# to be able to              114.378827
# my year old granddaughter  112.204068
# great addition to my       112.098192
# year old loves this        111.738970
# my grandson loved it       110.230090
# had so much fun            108.527534
# for my yr old              107.984613

# %% [markdown]
# #### Features that drive poor reviews
#
#     Top 7 features from our 4-6 n-gram vectorizer are:
#
# | N-Gram      | Score  |
# | ----------- | ----------- |
# | dont waste your money      | 131       |
# | do not buy this   | 78        |
# | not worth the money | 78 |
# | out of the box | 64 |
# | bought this for my | 44 |
# | would not recommend this | 39 |
# | not worth the price	 |	36 |
#
#
# </br> </br>
# </br> </br>
#
#
# The most important phrases from our TF-IDF analysis for positive reviews can be grouped into 2 main "concepts" or collocated phrases, groomed from across 3 to 6 ngram results for the most insightful features that are still human readable
#
#     1. Value Proposition Was lacking
#         - "dont waste your time"
#         - "not worth the money"
#
#     2. Dissatisfaction with quality of item
#         - "not work at all"
#         - "broke the first day"

# %%
vectorizer = TfidfVectorizer(ngram_range=(4, 6),
                             max_features=500, max_df = .8)
X = vectorizer.fit_transform(bad_cleaned_reviews)
terms = vectorizer.get_feature_names()

tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)

score = pd.DataFrame(tf_idf, columns=["score"])
score.sort_values(by="score", ascending=False, inplace=True)
score.head(50)
# Out:
#                                   score
# dont waste your money        130.507159
# do not buy this               78.245221
# not worth the money           77.731842
# out of the box                63.645846
# bought this for my            44.415243
# would not recommend this      39.333319
# not worth the price           36.059896
# total waste of money          34.366202
# to send it back               33.821013
# complete waste of money       33.121143
# thought it would be           29.314417
# right out of the              27.897751
# the quality of the            27.495270
# it out of the                 27.316088
# very disappointed in this     25.141077
# didnt work at all             24.933237
# broke the first day           24.766660
# dont waste your time          24.033096
# not work at all               23.717358
# for my year old               23.710944
# do not waste your             23.455842
# you get what you              22.088145
# had to return it              21.822807
# very disappointed with this   21.440362
# did not come with             21.273664
# was so excited to             21.144601
# not at all what               20.745896
# what waste of money           20.534584
# get what you pay              20.396504
# it did not work               20.271390
# your money on this            19.745405
# there is no way               19.732053
# what you pay for              19.212576
# very disappointed in the      19.096085
# would not buy again           19.018794
# to play with it               18.858894
# right out of the box          18.824527
# this is not the               18.805699
# get what you pay for          18.566263
# waste of money and            18.385037
# do not waste your money       18.356168
# not waste your money          18.356168
# was supposed to be            18.308451
# you get what you pay          18.300155
# and one of the                18.048535
# you get what you pay for      18.040751
# not buy this product          17.972508
# at the dollar store           17.921237
# if you want to                17.603388
# the quality of this           17.579311

# %%
vectorizer = TfidfVectorizer(ngram_range=(4, 4),
                             max_features=500, max_df = .8)
X = vectorizer.fit_transform(bad_cleaned_reviews)
terms = vectorizer.get_feature_names()

tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)

score = pd.DataFrame(tf_idf, columns=["score"])
score.sort_values(by="score", ascending=False, inplace=True)
score.head(50)
# Out:
#                                   score
# dont waste your money        134.427220
# not worth the money           78.308744
# do not buy this               76.523377
# out of the box                72.766264
# would not recommend this      43.844095
# bought this for my            43.266875
# not worth the price           36.377436
# total waste of money          34.737827
# to send it back               33.413432
# it out of the                 33.304878
# right out of the              32.994706
# complete waste of money       32.939516
# you get what you              29.428146
# thought it would be           29.032860
# do not waste your             28.431035
# get what you pay              28.091131
# the quality of the            27.368789
# very disappointed in this     26.852676
# what you pay for              26.709079
# for my year old               25.408859
# not work at all               24.635401
# broke the first day           24.604138
# your money on this            24.380928
# dont waste your time          24.133392
# very disappointed with this   23.826557
# not waste your money          23.455410
# not at all what               23.048297
# was so excited to             22.709436
# didnt work at all             22.394929
# waste your money on           21.697118
# had to return it              21.246857
# did not come with             20.984822
# there is no way               20.589997
# not buy this product          20.433989
# it did not work               20.401927
# not recommend this product    20.346454
# what waste of money           20.081088
# was supposed to be            19.788295
# waste of time and             19.684132
# this is not the               18.524010
# would not buy again           18.491495
# at the dollar store           18.181803
# did not work at               18.152281
# and one of the                17.967204
# very disappointed in the      17.914909
# waste of money and            17.911885
# save your money and           17.748473
# if you want to                17.590191
# nothing like the picture      17.240166
# bought it for my              17.204504

# %% [markdown]
# #### the most common issues that generated customer dissatisfaction.
#
# Below are some good candidates for reasons that have generated dissatisfaction, since we are interested in most common issues, we will use a standard count vectorizer as opposed to TFIDF:
#
#     -Quality issues
#     -Having to return the item
#     -Misaligned Expectations

# %%
vectorizer = CountVectorizer(ngram_range=(4, 4),
                             max_features=500, max_df = .8)
X = vectorizer.fit_transform(bad_cleaned_reviews)
terms = vectorizer.get_feature_names()

tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)
tf_idf = tf_idf.sum(axis=1)

score = pd.DataFrame(tf_idf, columns=["score"])
score.sort_values(by="score", ascending=False, inplace=True)
score.head(50)
# Out:
#                               score
# dont waste your money           179
# out of the box                  132
# do not buy this                 108
# not worth the money              96
# bought this for my               78
# would not recommend this         70
# it out of the                    60
# get what you pay                 54
# you get what you                 54
# right out of the                 52
# what you pay for                 51
# very disappointed in this        46
# not worth the price              45
# do not waste your                45
# to send it back                  43
# not work at all                  43
# waste your money on              43
# complete waste of money          42
# your money on this               42
# the quality of the               41
# was so excited to                41
# for my year old                  40
# total waste of money             40
# not waste your money             38
# very disappointed with this      38
# thought it would be              36
# not at all what                  35
# not recommend this product       34
# was supposed to be               34
# not buy this product             33
# did not work at                  31
# took it out of                   31
# broke the first day              31
# it did not work                  30
# waste of time and                30
# there is no way                  30
# dont waste your time             30
# for my sons birthday             29
# didnt work at all                29
# the quality of this              28
# very disappointed in the         28
# waste of money and               28
# save your money and              27
# was waste of money               27
# disappointed in this product     27
# to be able to                    26
# of time and money                26
# you are looking for              26
# what waste of money              26
# nothing like the picture         25

# %% [markdown]
# ## Similarity and Word Embeddings
#
# Using
# * `CountVectorizer`
# * `TfIdfVectorizer`
#
# Identify the most similar reviews from the McDonalds Yelp dataset.

# %% [markdown]
# In order to create effective and succient analysis we are reusing relevant code from previous analysis

# %%
import requests
from tqdm.notebook import tqdm
from bs4 import BeautifulSoup
from sklearn.metrics.pairwise import cosine_similarity
#Burger Menu list
url='https://www.mcdonalds.com/us/en-us/full-menu/burgers.html'
response = requests.get(url)
html=response.text
soup = BeautifulSoup(html,'html.parser')
burger_menu=[i.get_text() for i in soup.find_all('span',{'class':'categories-item-name'})]
cleaned_burger_menu = cleaner(burger_menu)
#Drinks Menu list
url='https://www.mcdonalds.com/us/en-us/full-menu/drinks.html'
response = requests.get(url)
html=response.text
soup = BeautifulSoup(html,'html.parser')
drink_menu=[i.get_text() for i in soup.find_all('span',{'class':'categories-item-name'})]
cleaned_drink_menu = cleaner(drink_menu)
#Breakfast Menu list
url='https://www.mcdonalds.com/us/en-us/full-menu/breakfast.html'
response = requests.get(url)
html=response.text
soup = BeautifulSoup(html,'html.parser')
breakfast_menu=[i.get_text() for i in soup.find_all('span',{'class':'categories-item-name'})]
cleaned_breakfast_menu = cleaner(breakfast_menu)
#Dessert Menu list
url='https://www.mcdonalds.com/us/en-us/full-menu/desserts-and-shakes.html'
response = requests.get(url)
html=response.text
soup = BeautifulSoup(html,'html.parser')
dessert_menu=[i.get_text() for i in soup.find_all('span',{'class':'categories-item-name'})]
cleaned_dessert_menu = cleaner(dessert_menu)
#McCafe Menu list
url='https://www.mcdonalds.com/us/en-us/full-menu/mccafe.html'
response = requests.get(url)
html=response.text
soup = BeautifulSoup(html,'html.parser')
cafe_menu=[i.get_text() for i in soup.find_all('span',{'class':'categories-item-name'})]
cleaned_cafe_menu = cleaner(cafe_menu)

# %%
#Tokenize each sentence, and remove stopwords
def token_rm_stopword(data : list):
    print('Tokenizing and removing stopwords...')
    temp_list=[]
    for i in tqdm(range(len(data)),desc='Loading...'):
        k=data[i]
        tok=nltk.word_tokenize(k)
        rem_stop_tok=[t for t in tok if t not in stopwords.words('english')]
        temp_list.append(" ".join(rem_stop_tok))
    return temp_list 
def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None
def lemmatize(data : list):
    print('Recommended to use after tokenization and stopword removal')
    print('lemmatizing each sentences')
    lemmatizer = WordNetLemmatizer()
    res_list=[]
    for i in tqdm(range(len(data)),desc='Loading...'):
        k=data[i]
        temp=k.split(" ")
        res_list.append(" ".join([lemmatizer.lemmatize(t) for t in temp]))
    return res_list
def spellcheck_word(data:list):
    print("Checking spellings for each line")
    words = set(map(lambda word: word.replace("\n", ""), open("20k.txt").readlines()))
    for i in tqdm(range(len(data)),desc='Loading'):
        line=data[i]
        res_line=[]
        for token in word_tokenize(line):
            new_tokens = []
            matches = difflib.get_close_matches(token.lower(), words, n=1, cutoff=0.7)
            if len(matches) == 0 or token.lower() in words:
                new_tokens.append(token)
            else:
                new_tokens.append(matches[0])
            res_line.append(" ".join(new_tokens))
    return res_line

# %% [markdown]
# ### Cleaning data

# %%
text = pd.read_csv('mcdonalds-yelp-negative-reviews.csv', encoding="ISO-8859-1")
mcd = pd.read_csv('mcdonalds-yelp-negative-reviews.csv', encoding="ISO-8859-1")

# %%
#Customized stopwords
nltk_stopwords=list(set(stopwords.words('english')))
new_stopwords=["i'm", 'hangout', 'spot', 'across', 'before', 'just', 'grab', 'spot',\
                                                    'filled', 'deal','little','having']
nltk_stopwords.extend(new_stopwords)

#Redundant word list & Dictionary
hamburger = ['hamburgers','burger','burgers','cheese burger']+cleaned_burger_menu
drink = ['drink','drinks','coke']+cleaned_drink_menu
breakfast = ['mcmuffin']+cleaned_breakfast_menu
dessert = ['mcflurry','cone','shake']+cleaned_dessert_menu
cafe = ['coffee']+cleaned_cafe_menu
facility = ['toilet','restroom','dirty','kitchen','cashier','parking','park','chair','chairs','dumpster']
servce = ['rude','impolite','sigh','sighed']


red_dict = {
    'hamburger':hamburger,
    'drink': drink,
    'breakfast':breakfast,
    'mcdonalds':['mcd','mcds','mcdonald'],
    'cafe':cafe,
    'facility':facility,
    'service':['service']
}
#I didn't know how to use the regex for multiple replacements, so I used a dictionary method.


#Customized stopwords
nltk_stopwords=list(set(stopwords.words('english')))
new_stopwords=["i'm", 'hangout', 'spot', 'across', 'before', 'just', 'grab', 'spot',\
                                                    'filled', 'deal','little','having']
nltk_stopwords.extend(new_stopwords)


# Lets iterate thru the review, removing punctuatation and numbers and creating word tokens using nltk word toeknize,
# next lets remove our custom stopwords and do some cleaning using regex to catch common concepts
# and map them back to a single concept (mcdonalds, hamburgers, nuggets)

#part of speech logic stolen from: https://www.programiz.com/python-programming/methods/set/update
cleaned_reviews = []
for idx, review in text.iterrows():
    # Clean punctuation
    clean_review = re.sub(r"[^A-Za-z ]",'',review['review'])
    # Tokenize into words and Tag words with part of speech 
    lemmatized_word = []
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(clean_review))  
    wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
    lemmatizer = WordNetLemmatizer()
    # lemetize, use part of speech if available
    for word, tag in wordnet_tagged:
        if tag is None:
            #if there is no available tag, append the token as is
            lemmatized_word.append(word)
        else:        
            #else use the tag to lemmatize the token
            lemmatized_word.append(lemmatizer.lemmatize(word, tag))
    words_clean = []
    for i in red_dict.items():
        if word in i[1]:
            word=i[0]
    for word in lemmatized_word:
        word = re.sub(r"(?:mcdonalds?|macdonalds?|mcds?)",'McDonald', word, flags=re.IGNORECASE)
        word = re.sub(r"(?:burgers?|cheeseburgers?|hamburgers?|hamburgersandwiches?)",'hamburger', word, flags=re.IGNORECASE)
        word = re.sub(r"(?:McNuggets?|nuggets?|nugs?)",'nuggets', word, flags=re.IGNORECASE)
        word = re.sub(r"(?:fries?|frys?|french fries?)",'fries', word, flags=re.IGNORECASE)
        word = re.sub(r"('toilet|restroom|dirty|kitchen|cashier|parking|park|chair?|dumpster')",'facility',\
                      word, flags=re.IGNORECASE)
        if word in new_stopwords:
            continue
        words_clean.append(word)
    cleaned_review = " ".join(words_clean)
    cleaned_reviews.append((cleaned_review))
                      
text['cleaned_reviews']=cleaned_reviews

# %%
cleaned_reviews = cleaner(cleaned_reviews)
cleaned_reviews = token_rm_stopword(cleaned_reviews)
cleaned_reviews_lem = lemmatize(cleaned_reviews)
# Out:
# Tokenizing and removing stopwords...
# Loading...:   0%|          | 0/1525 [00:00<?, ?it/s]
# Recommended to use after tokenization and stopword removal
# lemmatizing each sentences
# Loading...:   0%|          | 0/1525 [00:00<?, ?it/s]

# %% [markdown]
# ### Finding Similar reviews
#
# For finding similar reviews, I think it is better to have some slack on similarity, so that there are more similar reviews including almost identical ones. For such, I will have the threshold to 0.7. The threshold can be controlled based on the research objective in the future.

# %% [markdown]
# #### Using Count Vectorizer

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
vectorizer = CountVectorizer(lowercase=True, ngram_range=(2, 3),
                             max_features=12000)
X = vectorizer.fit_transform(cleaned_reviews) 
X = X.toarray()

corpus_df = pd.DataFrame(X, columns=vectorizer.get_feature_names())
# iterate through the Pandas dataframe, and drop the columns that reflect stopwords:
original_columns = corpus_df.columns # get existing columns


similarity_matrix = pd.DataFrame(cosine_similarity(corpus_df.values))

# %%
non_one = similarity_matrix[similarity_matrix <= .999]
empt_dic={}
for i in non_one.columns:
    li = non_one[i]
    if (max(li) >= 0.7):
        if  i <= li.index[li==max(li)]:
            empt_dic[i]=li.index[li==max(li)].to_list()

# %%
for i in empt_dic.keys():
    print(f'\nThe review number {i}\n\n {mcd.loc[i].review} \n\nis most similar to the review number {empt_dic[i][0]}\n\n{mcd.loc[empt_dic[i][0]].review}')
    print('-----------------------------------')
# Out:
# The review number 139
#
#  Worst McDonalds EVER!!!!!!!!!! They are unable to get an order correct, Went through the drive through last night got home and no Fries in my bag. Got to the window and the woman running the window was talking about her personal life with a co worker laughing it up with her back t us making us wait instead of giving us our ice coffee. Then she seemed to remember she was working and brought us our coffee. Last time I went there I ordered something with no mayo which my tix said... got home and covered in mayo. called up to complain and the response...What do u want me to do about it??? If I get the craving for Mcdonald's I will drive out of my way.. I hope this one goes out of business.... This location is good for nothing
#
# is most similar to the review number 140
#
# Worst McDonalds EVER!!!!!!!!!! They are unable to get an order correct, Went through the drive through last night got home and no Fries in my bag. Got to the window and the woman running the window was talking about her personal life with a co worker laughing it up with her back to us making us wait instead of giving us our ice coffee. Then she seemed to remember she was working and brought us our coffee. Last time I went there I ordered something with no mayo which my ticket said... got home and covered in mayo. called up to complain and the response...What do u want me to do about it??? I hope this one goes out of business.... This location is good for nothing, my husband and I if we ever go to another mcdonalds, it will be out of state!
# -----------------------------------
#
# The review number 154
#
#  Drive thru SUCKS here!!!! This is the 3rd time they messed up my order and there sooooo freakin slow! They have no since of urgency.
#
# is most similar to the review number 909
#
# The Hamburglar actually workz the drive thru. Because all I heard was rubble-rubble!
# -----------------------------------
#
# The review number 270
#
#  These guys never get any order right! How hard is it
#
# is most similar to the review number 387
#
# bleh-bad mcdonalds food.slow service.and never get orders right. ever.
# -----------------------------------
#
# The review number 846
#
#  They have bad service and very rude
#
# is most similar to the review number 1312
#
# Bad service, rude employee ! I will never go to this Mc Donald !
# -----------------------------------

# %% [markdown]
# #### Using TF-IDF

# %%
vectorizer = TfidfVectorizer(lowercase=True, ngram_range=(2, 3),
                             max_features=12000)
X = vectorizer.fit_transform(cleaned_reviews) 
X = X.toarray()

corpus_df = pd.DataFrame(X, columns=vectorizer.get_feature_names())
# iterate through the Pandas dataframe, and drop the columns that reflect stopwords:
original_columns = corpus_df.columns # get existing columns


similarity_matrix = pd.DataFrame(cosine_similarity(corpus_df.values))

# %%
non_one = similarity_matrix[similarity_matrix <= .999]
empt_dic={}
for i in non_one.columns:
    li = non_one[i]
    if (max(li) >= 0.7):
        if  i <= li.index[li==max(li)]:
            empt_dic[i]=li.index[li==max(li)].to_list()

# %%
for i in empt_dic.keys():
    print(f'\nThe review number {i}\n\n {mcd.loc[i].review} \n\nis most similar to the review number {empt_dic[i][0]}\n\n{mcd.loc[empt_dic[i][0]].review}')
    print('------------------------')
# Out:
# The review number 139
#
#  Worst McDonalds EVER!!!!!!!!!! They are unable to get an order correct, Went through the drive through last night got home and no Fries in my bag. Got to the window and the woman running the window was talking about her personal life with a co worker laughing it up with her back t us making us wait instead of giving us our ice coffee. Then she seemed to remember she was working and brought us our coffee. Last time I went there I ordered something with no mayo which my tix said... got home and covered in mayo. called up to complain and the response...What do u want me to do about it??? If I get the craving for Mcdonald's I will drive out of my way.. I hope this one goes out of business.... This location is good for nothing
#
# is most similar to the review number 140
#
# Worst McDonalds EVER!!!!!!!!!! They are unable to get an order correct, Went through the drive through last night got home and no Fries in my bag. Got to the window and the woman running the window was talking about her personal life with a co worker laughing it up with her back to us making us wait instead of giving us our ice coffee. Then she seemed to remember she was working and brought us our coffee. Last time I went there I ordered something with no mayo which my ticket said... got home and covered in mayo. called up to complain and the response...What do u want me to do about it??? I hope this one goes out of business.... This location is good for nothing, my husband and I if we ever go to another mcdonalds, it will be out of state!
# ------------------------
#
# The review number 270
#
#  These guys never get any order right! How hard is it
#
# is most similar to the review number 387
#
# bleh-bad mcdonalds food.slow service.and never get orders right. ever.
# ------------------------
#
# The review number 846
#
#  They have bad service and very rude
#
# is most similar to the review number 1312
#
# Bad service, rude employee ! I will never go to this Mc Donald !
# ------------------------

# %% [markdown]
# ### Findings
#
# Both Count and TFIDF vectorizer have similar results in finding similar reviews. However, when holding the threshold to 0.7, there are more reviews(4) in using count vectorizer compared to the result(3) of when using TF-IDF vectorizer.
